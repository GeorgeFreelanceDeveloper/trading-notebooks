# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="resources/logo.png"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Trends research
#
# Price change and the waves that result from those price changes generate trend. The price of a security moves through a series of waves in the direction of the trend (impulses), which are separated by a series of waves in opposite direction (corrections).
#
#
#
# [Follow this data in a CSV Spreadsheet](data/trends.csv)

# %% [markdown]
# ![purple-divider](resources/purple_divider.png)
#
# ## How identification trend
# The trend is simply the line of least resistance and therefore the traders job is to identify it and analyze its evolution to decide what type of strategy to adopt at any given time.
#
# When a market is climbing and encounters resistance (selling), it either overcomes that resistance or the price will reverse; the same happens when the price is falling and encounters resistance; it either overcomes all the buying or the price will reverse. Those turning points are critical moments and provide excellents zones in which to trade.
#
# ### Up-trend definition
# Up-trend is when two or more close candles are green (increasing) from context time-frame.
#
# Up-trend is when the price follows a series of growing impulses and corrections, where the peaks and troughs are increasingly higher from detail time-frame.
#
# ### Down-trend definition
# Down-trend is when two or more close candles are red (decreasing) from context time-frame.
#
# Down-trend is when the price follows a series of growing impulses and corrections, where the peaks and troughs are ever lower higher from detail time-frame.

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Trend categories

# %% [markdown]
# Trend are divided by their duration into three different categories: long, medium and short term. They can be categorized by how they fit in relation to the one above. In thoher words, a short-term trend will be observed within a medium-term trend, which in turn will be seen within a long-term trend.
#
# ### Long-term trend
# - time-frame for context: Y, 3M (overall long term trend 10Y)
# - traders: Position or investors
#
# ### Medium-term trend
# - time-frame for context: M, W
# - traders: swing
#
# ### Short-term trend
# - time-frame for context: D
# - traders: intraday
#
# Note: Time frame for detail is three lines lower (example Y -> 3M -> M)

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Hands on!

# %%
import os
import pandas as pd
from utils import transform_data, download_images

output_directory = "data/output"

# Init
if not os.path.exists(output_directory):
    os.mkdir(output_directory)

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Loading data

# %%
trends_raw = pd.read_csv("data/trends.csv")

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## The data at a glance

# %%
trends_raw
# Out:
#     ticker  long_term_trend_year long_term_trend_time_frame  \
# 0       DX                  1985                          Y
# 1       DX                  2021                         3M
# 2   EURUSD                  1976                          Y
# 3   EURUSD                  2021                         3M
# 4      SPX                  1982                          Y
# 5      SPX                  2020                         3M
# 6      NDQ                  1985                          Y
# 7      NDQ                  2022                         3M
# 8   BTCUSD                  2020                         3M
# 9   BTCUSD                  2022                         3M
# 10  ETHUSD                  2020                         3M
# 11  ETHUSD                  2022                         3M
# 12      GC                  1977                          Y
# 13      GC                  2022                         3M
# 14      CL                  2002                          Y
# 15      CL                  2020                         3M
# 16      KC                  1975                          Y
# 8   https://www.tradingview.com/x/RKl21f9y/
# 9   https://www.tradingview.com/x/ONq1ypGe/
# 10  https://www.tradingview.com/x/DIaYcxMe/
# 11  https://www.tradingview.com/x/jlEKKMst/
# 12  https://www.tradingview.com/x/qUjYVkOR/
# 13  https://www.tradingview.com/x/o9LW7TCa/
# 14  https://www.tradingview.com/x/aVxVOCVr/
# 15  https://www.tradingview.com/x/9Lp0b8Pd/
# 16  https://www.tradingview.com/x/m6QpLAxo/
# 17  https://www.tradingview.com/x/pTLkHGSV/
# 18  https://www.tradingview.com/x/CehN6ace/
# 19  https://www.tradingview.com/x/cJZo4M0N/
#
#                    medium_term_trend_detail long_term_trend_start  \
# 0   https://www.tradingview.com/x/Mz0EzygT/                   NaN
# 1   https://www.tradingview.com/x/aKP3EiuH/       center_rotation
# 2   https://www.tradingview.com/x/vEYqyuVW/       center_rotation
# 3   https://www.tradingview.com/x/Lfa08MHp/       center_rotation
# 4   https://www.tradingview.com/x/fiv878hf/       center_rotation
# 5   https://www.tradingview.com/x/OgchReGX/             liq_catch
# 6   https://www.tradingview.com/x/ic4Vnhaz/                   NaN
# 7   https://www.tradingview.com/x/zg7iQJDo/       center_rotation
# 8   https://www.tradingview.com/x/KBdIgq5r/       center_rotation
# 9   https://www.tradingview.com/x/KRKFzldk/       center_rotation
# 10  https://www.tradingview.com/x/aoCxer0n/       center_rotation
# 11  https://www.tradingview.com/x/emTa2a1R/       center_rotation
# 12  https://www.tradingview.com/x/vqx5xyhd/             liq_catch
# 13  https://www.tradingview.com/x/cWj8fH5b/             liq_catch
# 14  https://www.tradingview.com/x/yz0jmAww/       center_rotation
# 15  https://www.tradingview.com/x/q4GSXlxx/             liq_catch
# 16  https://www.tradingview.com/x/BCIBWMW3/             liq_catch
# 17  https://www.tradingview.com/x/SAITU6LC/       center_rotation
# 18  https://www.tradingview.com/x/x9j4V0FO/                   NaN
# 19  https://www.tradingview.com/x/IKlMyWgK/                   NaN
#
#    medium_term_trend_start                    long_term_trend_end  \
# 0          center_rotation  break_last_supply_zone_and_trend_line
# 1                liq_catch  break_last_demand_zone_and_trend_line
# 2          center_rotation  break_last_demand_zone_and_trend_line
# 3                liq_catch  break_last_supply_zone_and_trend_line
# 4                liq_catch                                    NaN
# 5                      NaN  break_last_demand_zone_and_trend_line
# 6                liq_catch                                    NaN
# 7          center_rotation                                    NaN
# 8          center_rotation  break_last_demand_zone_and_trend_line
# 9          center_rotation                                    NaN
# 10         center_rotation  break_last_demand_zone_and_trend_line
# 11               liq_catch                                    NaN
# 12               liq_catch                                    NaN
# 13               liq_catch  break_last_supply_zone_and_trend_line
# 14         center_rotation  break_last_demand_zone_and_trend_line
# 15         center_rotation  break_last_demand_zone_and_trend_line
# 16         center_rotation  break_last_demand_zone_and_trend_line
# 17               liq_catch  break_last_demand_zone_and_trend_line
# 18                     NaN                                    NaN
# 19                     NaN                                    NaN
#
#                     medium_term_trend_end  count_impulsive_waves  \
# 0   break_last_demand_zone_and_trend_line                    4.0
# 1   break_last_supply_zone_and_trend_line                    5.0
# 2   break_last_supply_zone_and_trend_line                    5.0
# 3   break_last_demand_zone_and_trend_line                    7.0
# 4   break_last_supply_zone_and_trend_line                    4.0
# 5   break_last_supply_zone_and_trend_line                    7.0
# 6   break_last_supply_zone_and_trend_line                    4.0
# 7   break_last_demand_zone_and_trend_line                    3.0
# 8   break_last_supply_zone_and_trend_line                    3.0
# 9   break_last_demand_zone_and_trend_line                    3.0
# 10  break_last_supply_zone_and_trend_line                    7.0
# 11  break_last_demand_zone_and_trend_line                    1.0
# 12  break_last_supply_zone_and_trend_line                    4.0
# 13  break_last_demand_zone_and_trend_line                    3.0
# 14  break_last_supply_zone_and_trend_line                    3.0
# 15  break_last_supply_zone_and_trend_line                    5.0
# 16  break_last_supply_zone_and_trend_line                    4.0
# 17  break_last_supply_zone_and_trend_line                    NaN
# 18                                    NaN                    NaN
# 19                                    NaN                    NaN
#
#     count_corrective_waves   reversal_pattern review  note
# 0                      3.0                NaN   True   NaN
# 1                      4.0                NaN   True   NaN
# 2                      4.0                NaN   True   NaN
# 3                      6.0                NaN   True   NaN
# 4                      3.0                NaN   True   NaN
# 5                      6.0                NaN   True   NaN
# 6                      3.0                NaN   True   NaN
# 7                      3.0                NaN   True   NaN
# 8                      2.0                NaN   True   NaN
# 9                      3.0                NaN   True   NaN
# 10                     6.0                NaN   True   NaN
# 11                     1.0                NaN   True   NaN
# 12                     3.0                NaN   True   NaN
# 13                     3.0                NaN   True   NaN
# 14                     2.0                NaN   True   NaN
# 15                     4.0                NaN   True   NaN
# 16                     3.0        v_rejection   True   NaN
# 17                     NaN  head_and_shoulder    NaN   NaN
# 18                     NaN                NaN    NaN   NaN
# 19                     NaN                NaN    NaN   NaN

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Transform data

# %%
trends = transform_data(trends_raw)

trends
# Out:
#              id  ticker  long_term_trend_year long_term_trend_time_frame  \
# 0       DX_1985      DX                  1985                          Y
# 1       DX_2021      DX                  2021                         3M
# 2   EURUSD_1976  EURUSD                  1976                          Y
# 3   EURUSD_2021  EURUSD                  2021                         3M
# 4      SPX_1982     SPX                  1982                          Y
# 5      SPX_2020     SPX                  2020                         3M
# 6      NDQ_1985     NDQ                  1985                          Y
# 7      NDQ_2022     NDQ                  2022                         3M
# 8   BTCUSD_2020  BTCUSD                  2020                         3M
# 9   BTCUSD_2022  BTCUSD                  2022                         3M
# 10  ETHUSD_2020  ETHUSD                  2020                         3M
# 11  ETHUSD_2022  ETHUSD                  2022                         3M
# 12      GC_1977      GC                  1977                          Y
# 13      GC_2022      GC                  2022                         3M
# 14      CL_2002      CL                  2002                          Y
# 15      CL_2020      CL                  2020                         3M
# 16      KC_1975      KC                  1975                          Y
# 8   https://www.tradingview.com/x/RKl21f9y/
# 9   https://www.tradingview.com/x/ONq1ypGe/
# 10  https://www.tradingview.com/x/DIaYcxMe/
# 11  https://www.tradingview.com/x/jlEKKMst/
# 12  https://www.tradingview.com/x/qUjYVkOR/
# 13  https://www.tradingview.com/x/o9LW7TCa/
# 14  https://www.tradingview.com/x/aVxVOCVr/
# 15  https://www.tradingview.com/x/9Lp0b8Pd/
# 16  https://www.tradingview.com/x/m6QpLAxo/
# 17  https://www.tradingview.com/x/pTLkHGSV/
# 18  https://www.tradingview.com/x/CehN6ace/
# 19  https://www.tradingview.com/x/cJZo4M0N/
#
#                    medium_term_trend_detail long_term_trend_start  \
# 0   https://www.tradingview.com/x/Mz0EzygT/                   NaN
# 1   https://www.tradingview.com/x/aKP3EiuH/       center_rotation
# 2   https://www.tradingview.com/x/vEYqyuVW/       center_rotation
# 3   https://www.tradingview.com/x/Lfa08MHp/       center_rotation
# 4   https://www.tradingview.com/x/fiv878hf/       center_rotation
# 5   https://www.tradingview.com/x/OgchReGX/             liq_catch
# 6   https://www.tradingview.com/x/ic4Vnhaz/                   NaN
# 7   https://www.tradingview.com/x/zg7iQJDo/       center_rotation
# 8   https://www.tradingview.com/x/KBdIgq5r/       center_rotation
# 9   https://www.tradingview.com/x/KRKFzldk/       center_rotation
# 10  https://www.tradingview.com/x/aoCxer0n/       center_rotation
# 11  https://www.tradingview.com/x/emTa2a1R/       center_rotation
# 12  https://www.tradingview.com/x/vqx5xyhd/             liq_catch
# 13  https://www.tradingview.com/x/cWj8fH5b/             liq_catch
# 14  https://www.tradingview.com/x/yz0jmAww/       center_rotation
# 15  https://www.tradingview.com/x/q4GSXlxx/             liq_catch
# 16  https://www.tradingview.com/x/BCIBWMW3/             liq_catch
# 17  https://www.tradingview.com/x/SAITU6LC/       center_rotation
# 18  https://www.tradingview.com/x/x9j4V0FO/                   NaN
# 19  https://www.tradingview.com/x/IKlMyWgK/                   NaN
#
#    medium_term_trend_start                    long_term_trend_end  \
# 0          center_rotation  break_last_supply_zone_and_trend_line
# 1                liq_catch  break_last_demand_zone_and_trend_line
# 2          center_rotation  break_last_demand_zone_and_trend_line
# 3                liq_catch  break_last_supply_zone_and_trend_line
# 4                liq_catch                                    NaN
# 5                      NaN  break_last_demand_zone_and_trend_line
# 6                liq_catch                                    NaN
# 7          center_rotation                                    NaN
# 8          center_rotation  break_last_demand_zone_and_trend_line
# 9          center_rotation                                    NaN
# 10         center_rotation  break_last_demand_zone_and_trend_line
# 11               liq_catch                                    NaN
# 12               liq_catch                                    NaN
# 13               liq_catch  break_last_supply_zone_and_trend_line
# 14         center_rotation  break_last_demand_zone_and_trend_line
# 15         center_rotation  break_last_demand_zone_and_trend_line
# 16         center_rotation  break_last_demand_zone_and_trend_line
# 17               liq_catch  break_last_demand_zone_and_trend_line
# 18                     NaN                                    NaN
# 19                     NaN                                    NaN
#
#                     medium_term_trend_end  count_impulsive_waves  \
# 0   break_last_demand_zone_and_trend_line                    4.0
# 1   break_last_supply_zone_and_trend_line                    5.0
# 2   break_last_supply_zone_and_trend_line                    5.0
# 3   break_last_demand_zone_and_trend_line                    7.0
# 4   break_last_supply_zone_and_trend_line                    4.0
# 5   break_last_supply_zone_and_trend_line                    7.0
# 6   break_last_supply_zone_and_trend_line                    4.0
# 7   break_last_demand_zone_and_trend_line                    3.0
# 8   break_last_supply_zone_and_trend_line                    3.0
# 9   break_last_demand_zone_and_trend_line                    3.0
# 10  break_last_supply_zone_and_trend_line                    7.0
# 11  break_last_demand_zone_and_trend_line                    1.0
# 12  break_last_supply_zone_and_trend_line                    4.0
# 13  break_last_demand_zone_and_trend_line                    3.0
# 14  break_last_supply_zone_and_trend_line                    3.0
# 15  break_last_supply_zone_and_trend_line                    5.0
# 16  break_last_supply_zone_and_trend_line                    4.0
# 17  break_last_supply_zone_and_trend_line                    NaN
# 18                                    NaN                    NaN
# 19                                    NaN                    NaN
#
#     count_corrective_waves   reversal_pattern review  note
# 0                      3.0                NaN   True   NaN
# 1                      4.0                NaN   True   NaN
# 2                      4.0                NaN   True   NaN
# 3                      6.0                NaN   True   NaN
# 4                      3.0                NaN   True   NaN
# 5                      6.0                NaN   True   NaN
# 6                      3.0                NaN   True   NaN
# 7                      3.0                NaN   True   NaN
# 8                      2.0                NaN   True   NaN
# 9                      3.0                NaN   True   NaN
# 10                     6.0                NaN   True   NaN
# 11                     1.0                NaN   True   NaN
# 12                     3.0                NaN   True   NaN
# 13                     3.0                NaN   True   NaN
# 14                     2.0                NaN   True   NaN
# 15                     4.0                NaN   True   NaN
# 16                     3.0        v_rejection   True   NaN
# 17                     NaN  head_and_shoulder    NaN   NaN
# 18                     NaN                NaN    NaN   NaN
# 19                     NaN                NaN    NaN   NaN

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Data processing

# %%
download_images(trends, output_directory)
# Out:
#        trend_id status
# 0       DX_1985     ok
# 1       DX_2021     ok
# 2   EURUSD_1976     ok
# 3   EURUSD_2021     ok
# 4      SPX_1982     ok
# 5      SPX_2020     ok
# 6      NDQ_1985     ok
# 7      NDQ_2022     ok
# 8   BTCUSD_2020     ok
# 9   BTCUSD_2022     ok
# 10  ETHUSD_2020     ok
# 11  ETHUSD_2022     ok
# 12      GC_1977     ok
# 13      GC_2022     ok
# 14      CL_2002     ok
# 15      CL_2020     ok
# 16      KC_1975     ok
# 17      KC_2021     ok
# 18     TLT_2018     ok
# 19     TLT_2022     ok

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Resources

# %% [markdown]
# * [The Wyckoff Methodology in Depth: How to trade financial markets logically, section trends - Rubén Villahermosa](https://www.amazon.com/Wyckoff-Methodology-Depth-financial-logically-ebook/dp/B07YXZ7VLZ)
