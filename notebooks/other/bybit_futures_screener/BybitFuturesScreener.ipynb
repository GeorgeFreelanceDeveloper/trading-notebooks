# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="resources/bybit_logo.png"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Bybit futures screener
#
# Application for screening interesting coins in Bybit futures exchange.
#
# [CoinMarketCap](https://coinmarketcap.com/)

# %% [markdown]
# ![purple-divider](resources/purple_divider.png)
#
# ## Hands on!

# %%
import pandas as pd
import requests
from utils import transform_data

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Loading data

# %%
BYBIT_TICKERS_URL = "https://api.bybit.com/derivatives/v3/public/tickers?category=linear"
BYBIT_INSTUMENTS_INFO_URL = "https://api.bybit.com/derivatives/v3/public/instruments-info?category=linear"

# Get all latest information for symbol
tickers_response = requests.get(BYBIT_TICKERS_URL).json()

# Get Instrument Info
instruments_info_response = requests.get(BYBIT_INSTUMENTS_INFO_URL).json()

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## The data at a glance

# %%
tickers_response
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': '10000NFTUSDT',
#     'bidPrice': '0.004635',
#     'askPrice': '0.004645',
#     'lastPrice': '0.004635',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.004645',
#     'price24hPcnt': '-0.002152',
#     'highPrice24h': '0.004720',
#     'lowPrice24h': '0.004595',
#     'prevPrice1h': '0.004620',
#     'markPrice': '0.004639',
#     'indexPrice': '0.004639',
#     'openInterest': '64350630',
#     'turnover24h': '74995.3648',
#     'volume24h': '16143100',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': '1000BONKUSDT',
#     'bidPrice': '0.001275',
#     'askPrice': '0.001277',
#     'lastPrice': '0.001275',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.001319',
#     'price24hPcnt': '-0.033358',
#     'highPrice24h': '0.001420',
#     'lowPrice24h': '0.001221',
#     'prevPrice1h': '0.001289',
#     'markPrice': '0.001274',
#     'indexPrice': '0.001271',
#     'openInterest': '10376498500',
#     'turnover24h': '19055104.2671',
#     'volume24h': '14468304200',
#     'fundingRate': '0.000721',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': '1000BTTUSDT',
#     'bidPrice': '0.000738',
#     'askPrice': '0.000739',
#     'lastPrice': '0.000738',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.000731',
#     'price24hPcnt': '0.009575',
#     'highPrice24h': '0.000739',
#     'lowPrice24h': '0.000729',
#     'prevPrice1h': '0.000738',
#     'markPrice': '0.000738',
#     'indexPrice': '0.000739',
#     'openInterest': '376806800',
#     'turnover24h': '119323.74229999',
#     'volume24h': '162256000',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': '1000LUNCUSDT',
#     'bidPrice': '0.1756',
#     'askPrice': '0.1757',
#     'lastPrice': '0.1756',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.1781',
#     'price24hPcnt': '-0.014037',
#     'highPrice24h': '0.1807',
#     'lowPrice24h': '0.1735',
#     'prevPrice1h': '0.1756',
#     'markPrice': '0.1756',
#     'indexPrice': '0.1756',
#     'openInterest': '17600958',
#     'turnover24h': '4731959.4353',
#     'volume24h': '26748911',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': '1000XECUSDT',
#     'bidPrice': '0.03124',
#     'askPrice': '0.03125',
#     'lastPrice': '0.03129',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.03037',
#     'price24hPcnt': '0.030293',
#     'highPrice24h': '0.03214',
#     'lowPrice24h': '0.02990',
#     'prevPrice1h': '0.03038',
#     'markPrice': '0.03128',
#     'indexPrice': '0.03127',
#     'openInterest': '4775320',
#     'turnover24h': '1884528.6189',
#     'volume24h': '60855420',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': '1INCHUSDT',
#     'bidPrice': '0.4735',
#     'askPrice': '0.4740',
#     'lastPrice': '0.4735',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.4885',
#     'price24hPcnt': '-0.030706',
#     'highPrice24h': '0.4970',
#     'lowPrice24h': '0.4640',
#     'prevPrice1h': '0.4670',
#     'markPrice': '0.4738',
#     'indexPrice': '0.4738',
#     'openInterest': '3825186.8',
#     'turnover24h': '2290224.10409999',
#     'volume24h': '4769472.5',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AAVEUSDT',
#     'bidPrice': '84.60',
#     'askPrice': '84.65',
#     'lastPrice': '84.65',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '84.10',
#     'price24hPcnt': '0.006539',
#     'highPrice24h': '91.35',
#     'lowPrice24h': '82.90',
#     'prevPrice1h': '84.15',
#     'markPrice': '84.62',
#     'indexPrice': '84.52',
#     'openInterest': '81125.53',
#     'turnover24h': '52636056.38450005',
#     'volume24h': '606089.15999999',
#     'fundingRate': '0.000307',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ACHUSDT',
#     'bidPrice': '0.01123',
#     'askPrice': '0.01125',
#     'lastPrice': '0.01125',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.01203',
#     'price24hPcnt': '-0.064837',
#     'highPrice24h': '0.01237',
#     'lowPrice24h': '0.01103',
#     'prevPrice1h': '0.01161',
#     'markPrice': '0.01125',
#     'indexPrice': '0.01123',
#     'openInterest': '98970620',
#     'turnover24h': '7001419.77269999',
#     'volume24h': '589545370',
#     'fundingRate': '0.000137',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ADAPERP',
#     'bidPrice': '0.3480',
#     'askPrice': '0.3484',
#     'lastPrice': '0.3480',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.3544',
#     'price24hPcnt': '-0.018058',
#     'highPrice24h': '0.3573',
#     'lowPrice24h': '0.3443',
#     'prevPrice1h': '0.3469',
#     'markPrice': '0.3481',
#     'indexPrice': '0.3483',
#     'openInterest': '1214054',
#     'turnover24h': '138294.24619999',
#     'volume24h': '395092',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ADAUSDT',
#     'bidPrice': '0.3482',
#     'askPrice': '0.3483',
#     'lastPrice': '0.3483',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.3543',
#     'price24hPcnt': '-0.016934',
#     'highPrice24h': '0.3577',
#     'lowPrice24h': '0.3438',
#     'prevPrice1h': '0.3468',
#     'markPrice': '0.3483',
#     'indexPrice': '0.3483',
#     'openInterest': '57678658',
#     'turnover24h': '39236615.82109993',
#     'volume24h': '112029916',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AGLDUSDT',
#     'bidPrice': '0.3130',
#     'askPrice': '0.3135',
#     'lastPrice': '0.3135',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.3380',
#     'price24hPcnt': '-0.072485',
#     'highPrice24h': '0.3380',
#     'lowPrice24h': '0.3100',
#     'prevPrice1h': '0.3115',
#     'markPrice': '0.3130',
#     'indexPrice': '0.3130',
#     'openInterest': '427788',
#     'turnover24h': '421974.23519999',
#     'volume24h': '1303045.79999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AKROUSDT',
#     'bidPrice': '0.003408',
#     'askPrice': '0.003411',
#     'lastPrice': '0.003407',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.003516',
#     'price24hPcnt': '-0.031001',
#     'highPrice24h': '0.003577',
#     'lowPrice24h': '0.003365',
#     'prevPrice1h': '0.003408',
#     'markPrice': '0.003410',
#     'indexPrice': '0.003410',
#     'openInterest': '191062300',
#     'turnover24h': '919220.7557',
#     'volume24h': '264233900',
#     'fundingRate': '0.00069',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ALGOUSDT',
#     'bidPrice': '0.2250',
#     'askPrice': '0.2255',
#     'lastPrice': '0.2250',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.2330',
#     'price24hPcnt': '-0.034334',
#     'highPrice24h': '0.2370',
#     'lowPrice24h': '0.2225',
#     'prevPrice1h': '0.2245',
#     'markPrice': '0.2251',
#     'indexPrice': '0.2251',
#     'openInterest': '18573596.5',
#     'turnover24h': '10733007.75519999',
#     'volume24h': '46604402.39999995',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ALICEUSDT',
#     'bidPrice': '1.480',
#     'askPrice': '1.485',
#     'lastPrice': '1.480',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '1.590',
#     'price24hPcnt': '-0.069182',
#     'highPrice24h': '1.605',
#     'lowPrice24h': '1.445',
#     'prevPrice1h': '1.465',
#     'markPrice': '1.481',
#     'indexPrice': '1.481',
#     'openInterest': '648756.69999999',
#     'turnover24h': '4242327.0485',
#     'volume24h': '2781478.6',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ALPHAUSDT',
#     'bidPrice': '0.12415',
#     'askPrice': '0.12420',
#     'lastPrice': '0.12425',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.12270',
#     'price24hPcnt': '0.012632',
#     'highPrice24h': '0.12545',
#     'lowPrice24h': '0.11820',
#     'prevPrice1h': '0.12290',
#     'markPrice': '0.12420',
#     'indexPrice': '0.12409',
#     'openInterest': '16669216',
#     'turnover24h': '8661465.67584999',
#     'volume24h': '70756100',
#     'fundingRate': '0.000183',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ANKRUSDT',
#     'bidPrice': '0.02365',
#     'askPrice': '0.02370',
#     'lastPrice': '0.02370',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.02365',
#     'price24hPcnt': '0.002114',
#     'highPrice24h': '0.02550',
#     'lowPrice24h': '0.02295',
#     'prevPrice1h': '0.02395',
#     'markPrice': '0.02370',
#     'indexPrice': '0.02366',
#     'openInterest': '115535653',
#     'turnover24h': '6256066.79334999',
#     'volume24h': '259442329',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ANTUSDT',
#     'bidPrice': '2.530',
#     'askPrice': '2.535',
#     'lastPrice': '2.530',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '2.695',
#     'price24hPcnt': '-0.061224',
#     'highPrice24h': '2.715',
#     'lowPrice24h': '2.500',
#     'prevPrice1h': '2.525',
#     'markPrice': '2.532',
#     'indexPrice': '2.533',
#     'openInterest': '507480',
#     'turnover24h': '1742476.861',
#     'volume24h': '669485.99999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'APEPERP',
#     'bidPrice': '4.829',
#     'askPrice': '4.835',
#     'lastPrice': '4.835',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '5.032',
#     'price24hPcnt': '-0.039149',
#     'highPrice24h': '5.110',
#     'lowPrice24h': '4.755',
#     'prevPrice1h': '4.817',
#     'markPrice': '4.834',
#     'indexPrice': '4.846',
#     'openInterest': '102963.8',
#     'turnover24h': '270866.50229999',
#     'volume24h': '54749.69999999',
#     'fundingRate': '-0.000753',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'APEUSDT',
#     'bidPrice': '4.836',
#     'askPrice': '4.837',
#     'lastPrice': '4.837',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '5.036',
#     'price24hPcnt': '-0.039515',
#     'highPrice24h': '5.114',
#     'lowPrice24h': '4.747',
#     'prevPrice1h': '4.826',
#     'markPrice': '4.837',
#     'indexPrice': '4.844',
#     'openInterest': '3886143.5',
#     'turnover24h': '49556980.95239991',
#     'volume24h': '10056542.79999999',
#     'fundingRate': '-0.000791',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'API3USDT',
#     'bidPrice': '1.367',
#     'askPrice': '1.368',
#     'lastPrice': '1.366',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '1.419',
#     'price24hPcnt': '-0.03735',
#     'highPrice24h': '1.430',
#     'lowPrice24h': '1.348',
#     'prevPrice1h': '1.359',
#     'markPrice': '1.366',
#     'indexPrice': '1.366',
#     'openInterest': '414906.6',
#     'turnover24h': '560295.26609999',
#     'volume24h': '402443.4',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'APTPERP',
#     'bidPrice': '7.630',
#     'askPrice': '7.635',
#     'lastPrice': '7.630',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '8.070',
#     'price24hPcnt': '-0.054522',
#     'highPrice24h': '8.170',
#     'lowPrice24h': '7.405',
#     'prevPrice1h': '7.620',
#     'markPrice': '7.632',
#     'indexPrice': '7.635',
#     'openInterest': '55585.64',
#     'turnover24h': '818960.45109999',
#     'volume24h': '105363.52999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'APTUSDT',
#     'bidPrice': '7.635',
#     'askPrice': '7.640',
#     'lastPrice': '7.635',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '8.075',
#     'price24hPcnt': '-0.054489',
#     'highPrice24h': '8.185',
#     'lowPrice24h': '7.390',
#     'prevPrice1h': '7.630',
#     'markPrice': '7.634',
#     'indexPrice': '7.634',
#     'openInterest': '2636775.48',
#     'turnover24h': '139262735.30819985',
#     'volume24h': '17887269.70999997',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ARPAUSDT',
#     'bidPrice': '0.03391',
#     'askPrice': '0.03392',
#     'lastPrice': '0.03392',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.03416',
#     'price24hPcnt': '-0.007025',
#     'highPrice24h': '0.03463',
#     'lowPrice24h': '0.03345',
#     'prevPrice1h': '0.03368',
#     'markPrice': '0.03392',
#     'indexPrice': '0.03391',
#     'openInterest': '6010870',
#     'turnover24h': '155817.8569',
#     'volume24h': '4560280',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ARUSDT',
#     'bidPrice': '9.17',
#     'askPrice': '9.18',
#     'lastPrice': '9.18',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '9.41',
#     'price24hPcnt': '-0.024442',
#     'highPrice24h': '9.77',
#     'lowPrice24h': '9.04',
#     'prevPrice1h': '9.14',
#     'markPrice': '9.18',
#     'indexPrice': '9.17',
#     'openInterest': '116727.4',
#     'turnover24h': '7456227.32199999',
#     'volume24h': '784221.69999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ASTRUSDT',
#     'bidPrice': '0.04380',
#     'askPrice': '0.04385',
#     'lastPrice': '0.04385',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.04350',
#     'price24hPcnt': '0.008045',
#     'highPrice24h': '0.04490',
#     'lowPrice24h': '0.04190',
#     'prevPrice1h': '0.04395',
#     'markPrice': '0.04381',
#     'indexPrice': '0.04379',
#     'openInterest': '25099791',
#     'turnover24h': '775676.3845',
#     'volume24h': '17988721',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ATOMPERP',
#     'bidPrice': '12.175',
#     'askPrice': '12.190',
#     'lastPrice': '12.175',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '12.540',
#     'price24hPcnt': '-0.029106',
#     'highPrice24h': '12.635',
#     'lowPrice24h': '12.030',
#     'prevPrice1h': '12.110',
#     'markPrice': '12.183',
#     'indexPrice': '12.191',
#     'openInterest': '60925.6',
#     'turnover24h': '125917.343',
#     'volume24h': '10244.99999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ATOMUSDT',
#     'bidPrice': '12.190',
#     'askPrice': '12.195',
#     'lastPrice': '12.190',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '12.550',
#     'price24hPcnt': '-0.028685',
#     'highPrice24h': '12.660',
#     'lowPrice24h': '12.045',
#     'prevPrice1h': '12.105',
#     'markPrice': '12.191',
#     'indexPrice': '12.190',
#     'openInterest': '1767896.5',
#     'turnover24h': '36684860.67849998',
#     'volume24h': '2976448.19999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AUDIOUSDT',
#     'bidPrice': '0.1820',
#     'askPrice': '0.1825',
#     'lastPrice': '0.1825',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.1895',
#     'price24hPcnt': '-0.036939',
#     'highPrice24h': '0.1910',
#     'lowPrice24h': '0.1785',
#     'prevPrice1h': '0.1810',
#     'markPrice': '0.1823',
#     'indexPrice': '0.1822',
#     'openInterest': '3790912.4',
#     'turnover24h': '534556.51095',
#     'volume24h': '2896509.6',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AVAXPERP',
#     'bidPrice': '16.935',
#     'askPrice': '16.950',
#     'lastPrice': '16.935',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '16.880',
#     'price24hPcnt': '0.003258',
#     'highPrice24h': '18.220',
#     'lowPrice24h': '16.690',
#     'prevPrice1h': '16.900',
#     'markPrice': '16.935',
#     'indexPrice': '16.933',
#     'openInterest': '19169.84',
#     'turnover24h': '1039723.5496',
#     'volume24h': '60055.86',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AVAXUSDT',
#     'bidPrice': '16.940',
#     'askPrice': '16.945',
#     'lastPrice': '16.945',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '16.885',
#     'price24hPcnt': '0.003553',
#     'highPrice24h': '18.245',
#     'lowPrice24h': '16.690',
#     'prevPrice1h': '16.890',
#     'markPrice': '16.936',
#     'indexPrice': '16.932',
#     'openInterest': '991326.5',
#     'turnover24h': '112415927.4329999',
#     'volume24h': '6468655.39999998',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'AXSUSDT',
#     'bidPrice': '8.830',
#     'askPrice': '8.835',
#     'lastPrice': '8.830',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '9.075',
#     'price24hPcnt': '-0.026997',
#     'highPrice24h': '9.130',
#     'lowPrice24h': '8.545',
#     'prevPrice1h': '8.715',
#     'markPrice': '8.830',
#     'indexPrice': '8.830',
#     'openInterest': '763438.7',
#     'turnover24h': '33224795.31699997',
#     'volume24h': '3752915.6',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BAKEUSDT',
#     'bidPrice': '0.1625',
#     'askPrice': '0.1630',
#     'lastPrice': '0.1625',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.1695',
#     'price24hPcnt': '-0.041297',
#     'highPrice24h': '0.1720',
#     'lowPrice24h': '0.1595',
#     'prevPrice1h': '0.1615',
#     'markPrice': '0.1625',
#     'indexPrice': '0.1625',
#     'openInterest': '3573264.7',
#     'turnover24h': '493882.72839999',
#     'volume24h': '2968082.2',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BALUSDT',
#     'bidPrice': '6.745',
#     'askPrice': '6.750',
#     'lastPrice': '6.740',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '6.640',
#     'price24hPcnt': '0.01506',
#     'highPrice24h': '6.880',
#     'lowPrice24h': '6.600',
#     'prevPrice1h': '6.675',
#     'markPrice': '6.741',
#     'indexPrice': '6.741',
#     'openInterest': '164509.7',
#     'turnover24h': '1769691.12544999',
#     'volume24h': '262660.01',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BANDUSDT',
#     'bidPrice': '1.843',
#     'askPrice': '1.844',
#     'lastPrice': '1.844',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '1.881',
#     'price24hPcnt': '-0.01967',
#     'highPrice24h': '1.920',
#     'lowPrice24h': '1.818',
#     'prevPrice1h': '1.833',
#     'markPrice': '1.843',
#     'indexPrice': '1.842',
#     'openInterest': '587370.6',
#     'turnover24h': '2427742.65549999',
#     'volume24h': '1294347.4',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BATUSDT',
#     'bidPrice': '0.2370',
#     'askPrice': '0.2375',
#     'lastPrice': '0.2375',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.2310',
#     'price24hPcnt': '0.028138',
#     'highPrice24h': '0.2450',
#     'lowPrice24h': '0.2285',
#     'prevPrice1h': '0.2310',
#     'markPrice': '0.2375',
#     'indexPrice': '0.2375',
#     'openInterest': '2388530.5',
#     'turnover24h': '1153703.77105',
#     'volume24h': '4916049.6',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BCHUSDT',
#     'bidPrice': '124.65',
#     'askPrice': '124.70',
#     'lastPrice': '124.65',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '124.95',
#     'price24hPcnt': '-0.0024',
#     'highPrice24h': '127.40',
#     'lowPrice24h': '121.80',
#     'prevPrice1h': '124.55',
#     'markPrice': '124.68',
#     'indexPrice': '124.68',
#     'openInterest': '66348.47',
#     'turnover24h': '12744778.02149998',
#     'volume24h': '102536.14999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BELUSDT',
#     'bidPrice': '0.4943',
#     'askPrice': '0.4945',
#     'lastPrice': '0.4942',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.5078',
#     'price24hPcnt': '-0.026782',
#     'highPrice24h': '0.5126',
#     'lowPrice24h': '0.4881',
#     'prevPrice1h': '0.4905',
#     'markPrice': '0.4939',
#     'indexPrice': '0.4939',
#     'openInterest': '367919',
#     'turnover24h': '979099.01449999',
#     'volume24h': '1950239',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BICOUSDT',
#     'bidPrice': '0.3356',
#     'askPrice': '0.3357',
#     'lastPrice': '0.3356',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.3472',
#     'price24hPcnt': '-0.03341',
#     'highPrice24h': '0.3488',
#     'lowPrice24h': '0.3315',
#     'prevPrice1h': '0.3333',
#     'markPrice': '0.3347',
#     'indexPrice': '0.3341',
#     'openInterest': '499492.2',
#     'turnover24h': '509759.04109',
#     'volume24h': '1505422.19999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BITUSDT',
#     'bidPrice': '0.4950',
#     'askPrice': '0.4951',
#     'lastPrice': '0.4952',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.5176',
#     'price24hPcnt': '-0.043276',
#     'highPrice24h': '0.5182',
#     'lowPrice24h': '0.4880',
#     'prevPrice1h': '0.5007',
#     'markPrice': '0.4952',
#     'indexPrice': '0.4949',
#     'openInterest': '67240559.7',
#     'turnover24h': '21838653.25296',
#     'volume24h': '43085322.60000006',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BLZUSDT',
#     'bidPrice': '0.06315',
#     'askPrice': '0.06320',
#     'lastPrice': '0.06320',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.06530',
#     'price24hPcnt': '-0.032159',
#     'highPrice24h': '0.06645',
#     'lowPrice24h': '0.06190',
#     'prevPrice1h': '0.06300',
#     'markPrice': '0.06320',
#     'indexPrice': '0.06320',
#     'openInterest': '6116761',
#     'turnover24h': '1718120.9408',
#     'volume24h': '26664534',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BNBPERP',
#     'bidPrice': '301.15',
#     'askPrice': '301.40',
#     'lastPrice': '301.15',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '302.45',
#     'price24hPcnt': '-0.004298',
#     'highPrice24h': '305.45',
#     'lowPrice24h': '298.25',
#     'prevPrice1h': '301.15',
#     'markPrice': '301.23',
#     'indexPrice': '301.41',
#     'openInterest': '3441.86',
#     'turnover24h': '447031.025',
#     'volume24h': '1475.30999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BNBUSDT',
#     'bidPrice': '301.30',
#     'askPrice': '301.35',
#     'lastPrice': '301.30',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '302.50',
#     'price24hPcnt': '-0.003966',
#     'highPrice24h': '305.75',
#     'lowPrice24h': '298.20',
#     'prevPrice1h': '301.25',
#     'markPrice': '301.35',
#     'indexPrice': '301.41',
#     'openInterest': '130419.88',
#     'turnover24h': '36891060.75699999',
#     'volume24h': '122190.29999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BNXUSDT',
#     'bidPrice': '81.40',
#     'askPrice': '81.45',
#     'lastPrice': '81.40',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '80.15',
#     'price24hPcnt': '0.015595',
#     'highPrice24h': '82.10',
#     'lowPrice24h': '78.75',
#     'prevPrice1h': '81.05',
#     'markPrice': '81.40',
#     'indexPrice': '81.40',
#     'openInterest': '54088.37',
#     'turnover24h': '4310801.54149999',
#     'volume24h': '53496.4',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BOBAUSDT',
#     'bidPrice': '0.2110',
#     'askPrice': '0.2115',
#     'lastPrice': '0.2110',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.2100',
#     'price24hPcnt': '0.004761',
#     'highPrice24h': '0.2190',
#     'lowPrice24h': '0.2095',
#     'prevPrice1h': '0.2115',
#     'markPrice': '0.2115',
#     'indexPrice': '0.2127',
#     'openInterest': '544396.19999999',
#     'turnover24h': '285599.3492',
#     'volume24h': '1333806',
#     'fundingRate': '-0.002418',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BSVUSDT',
#     'bidPrice': '44.70',
#     'askPrice': '44.75',
#     'lastPrice': '44.70',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '44.95',
#     'price24hPcnt': '-0.005561',
#     'highPrice24h': '45.45',
#     'lowPrice24h': '43.40',
#     'prevPrice1h': '44.50',
#     'markPrice': '44.72',
#     'indexPrice': '44.74',
#     'openInterest': '21285.93999999',
#     'turnover24h': '899181.78599999',
#     'volume24h': '20186.58',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BSWUSDT',
#     'bidPrice': '0.1969',
#     'askPrice': '0.1971',
#     'lastPrice': '0.1971',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.1999',
#     'price24hPcnt': '-0.014007',
#     'highPrice24h': '0.2053',
#     'lowPrice24h': '0.1955',
#     'prevPrice1h': '0.1964',
#     'markPrice': '0.1971',
#     'indexPrice': '0.1971',
#     'openInterest': '4538531',
#     'turnover24h': '646183.3091',
#     'volume24h': '3236439',
#     'fundingRate': '0.00007',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BTCPERP',
#     'bidPrice': '21232.50',
#     'askPrice': '21233.00',
#     'lastPrice': '21232.50',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '21255.50',
#     'price24hPcnt': '-0.001082',
#     'highPrice24h': '21630.50',
#     'lowPrice24h': '21032.50',
#     'prevPrice1h': '21211.50',
#     'markPrice': '21234.84',
#     'indexPrice': '21238.46',
#     'openInterest': '1103.45599999',
#     'turnover24h': '27321491.11150003',
#     'volume24h': '1285.24999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'BTCUSDT',
#     'bidPrice': '21222.50',
#     'askPrice': '21223.00',
#     'lastPrice': '21223.00',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '21244.50',
#     'price24hPcnt': '-0.001012',
#     'highPrice24h': '21626.50',
#     'lowPrice24h': '20985.00',
#     'prevPrice1h': '21201.50',
#     'markPrice': '21226.06',
#     'indexPrice': '21236.67',
#     'openInterest': '55211.301',
#     'turnover24h': '3178066822.559499',
#     'volume24h': '149570.97',
#     'fundingRate': '-0.000076',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'C98USDT',
#     'bidPrice': '0.2200',
#     'askPrice': '0.2205',
#     'lastPrice': '0.2205',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.2205',
#     'price24hPcnt': '0',
#     'highPrice24h': '0.2255',
#     'lowPrice24h': '0.2150',
#     'prevPrice1h': '0.2200',
#     'markPrice': '0.2203',
#     'indexPrice': '0.2200',
#     'openInterest': '3047796.2',
#     'turnover24h': '1344767.54499999',
#     'volume24h': '6101981.4',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CEEKUSDT',
#     'bidPrice': '0.10590',
#     'askPrice': '0.10615',
#     'lastPrice': '0.10610',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.10025',
#     'price24hPcnt': '0.058354',
#     'highPrice24h': '0.11000',
#     'lowPrice24h': '0.09825',
#     'prevPrice1h': '0.10740',
#     'markPrice': '0.10610',
#     'indexPrice': '0.10607',
#     'openInterest': '3382141',
#     'turnover24h': '1823736.86844999',
#     'volume24h': '17406308',
#     'fundingRate': '0.000171',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CELOUSDT',
#     'bidPrice': '0.671',
#     'askPrice': '0.672',
#     'lastPrice': '0.671',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.703',
#     'price24hPcnt': '-0.045519',
#     'highPrice24h': '0.712',
#     'lowPrice24h': '0.662',
#     'prevPrice1h': '0.671',
#     'markPrice': '0.671',
#     'indexPrice': '0.671',
#     'openInterest': '1393805.7',
#     'turnover24h': '8342012.97049999',
#     'volume24h': '12107664.49999999',
#     'fundingRate': '0.000543',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CELRUSDT',
#     'bidPrice': '0.01380',
#     'askPrice': '0.01385',
#     'lastPrice': '0.01380',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.01410',
#     'price24hPcnt': '-0.021276',
#     'highPrice24h': '0.01430',
#     'lowPrice24h': '0.01355',
#     'prevPrice1h': '0.01375',
#     'markPrice': '0.01381',
#     'indexPrice': '0.01381',
#     'openInterest': '70774979',
#     'turnover24h': '460955.80605',
#     'volume24h': '32973898',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CHRUSDT',
#     'bidPrice': '0.1416',
#     'askPrice': '0.1418',
#     'lastPrice': '0.1418',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.1459',
#     'price24hPcnt': '-0.028101',
#     'highPrice24h': '0.1478',
#     'lowPrice24h': '0.1395',
#     'prevPrice1h': '0.1408',
#     'markPrice': '0.1417',
#     'indexPrice': '0.1416',
#     'openInterest': '4548846.7',
#     'turnover24h': '879282.11997999',
#     'volume24h': '6105425.09999998',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CHZPERP',
#     'bidPrice': '0.13655',
#     'askPrice': '0.13660',
#     'lastPrice': '0.13650',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.13695',
#     'price24hPcnt': '-0.003285',
#     'highPrice24h': '0.13950',
#     'lowPrice24h': '0.13365',
#     'prevPrice1h': '0.13555',
#     'markPrice': '0.13660',
#     'indexPrice': '0.13659',
#     'openInterest': '925710',
#     'turnover24h': '80550.91',
#     'volume24h': '589462',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CHZUSDT',
#     'bidPrice': '0.13655',
#     'askPrice': '0.13660',
#     'lastPrice': '0.13655',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.13700',
#     'price24hPcnt': '-0.003284',
#     'highPrice24h': '0.13955',
#     'lowPrice24h': '0.13360',
#     'prevPrice1h': '0.13550',
#     'markPrice': '0.13658',
#     'indexPrice': '0.13657',
#     'openInterest': '54371620',
#     'turnover24h': '19662728.89444998',
#     'volume24h': '144022624',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CKBUSDT',
#     'bidPrice': '0.003180',
#     'askPrice': '0.003185',
#     'lastPrice': '0.003185',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.003420',
#     'price24hPcnt': '-0.068713',
#     'highPrice24h': '0.003440',
#     'lowPrice24h': '0.003165',
#     'prevPrice1h': '0.003185',
#     'markPrice': '0.003186',
#     'indexPrice': '0.003189',
#     'openInterest': '71029080',
#     'turnover24h': '156908.46944999',
#     'volume24h': '47643020',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'COMPUSDT',
#     'bidPrice': '51.15',
#     'askPrice': '51.20',
#     'lastPrice': '51.20',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '52.30',
#     'price24hPcnt': '-0.021032',
#     'highPrice24h': '54.70',
#     'lowPrice24h': '50.05',
#     'prevPrice1h': '50.50',
#     'markPrice': '51.20',
#     'indexPrice': '51.17',
#     'openInterest': '44559.85',
#     'turnover24h': '6553895.5745',
#     'volume24h': '125348.13',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'COTIUSDT',
#     'bidPrice': '0.0724',
#     'askPrice': '0.0725',
#     'lastPrice': '0.0724',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.0748',
#     'price24hPcnt': '-0.032085',
#     'highPrice24h': '0.0760',
#     'lowPrice24h': '0.0722',
#     'prevPrice1h': '0.0729',
#     'markPrice': '0.0725',
#     'indexPrice': '0.0725',
#     'openInterest': '9431957',
#     'turnover24h': '650117.2295',
#     'volume24h': '8723691',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CREAMUSDT',
#     'bidPrice': '13.002',
#     'askPrice': '13.009',
#     'lastPrice': '12.998',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '13.296',
#     'price24hPcnt': '-0.022412',
#     'highPrice24h': '13.551',
#     'lowPrice24h': '12.839',
#     'prevPrice1h': '13.175',
#     'markPrice': '12.996',
#     'indexPrice': '12.994',
#     'openInterest': '60945.71',
#     'turnover24h': '793996.56509',
#     'volume24h': '59815.23',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CROUSDT',
#     'bidPrice': '0.07675',
#     'askPrice': '0.07680',
#     'lastPrice': '0.07680',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.07860',
#     'price24hPcnt': '-0.0229',
#     'highPrice24h': '0.08040',
#     'lowPrice24h': '0.07550',
#     'prevPrice1h': '0.07615',
#     'markPrice': '0.07667',
#     'indexPrice': '0.07667',
#     'openInterest': '47374105',
#     'turnover24h': '2824530.06499999',
#     'volume24h': '36207579',
#     'fundingRate': '-0.00019',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CRVUSDT',
#     'bidPrice': '0.939',
#     'askPrice': '0.940',
#     'lastPrice': '0.939',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.900',
#     'price24hPcnt': '0.043333',
#     'highPrice24h': '0.957',
#     'lowPrice24h': '0.889',
#     'prevPrice1h': '0.931',
#     'markPrice': '0.939',
#     'indexPrice': '0.940',
#     'openInterest': '7274124.8',
#     'turnover24h': '42526762.71239996',
#     'volume24h': '45802326.49999998',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CTCUSDT',
#     'bidPrice': '0.55585',
#     'askPrice': '0.55630',
#     'lastPrice': '0.55535',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.56460',
#     'price24hPcnt': '-0.016383',
#     'highPrice24h': '0.58770',
#     'lowPrice24h': '0.54765',
#     'prevPrice1h': '0.55650',
#     'markPrice': '0.55535',
#     'indexPrice': '0.55474',
#     'openInterest': '753010',
#     'turnover24h': '925236.72075',
#     'volume24h': '1627611',
#     'fundingRate': '0.000447',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CTKUSDT',
#     'bidPrice': '0.778',
#     'askPrice': '0.779',
#     'lastPrice': '0.778',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.782',
#     'price24hPcnt': '-0.005115',
#     'highPrice24h': '0.806',
#     'lowPrice24h': '0.759',
#     'prevPrice1h': '0.769',
#     'markPrice': '0.778',
#     'indexPrice': '0.778',
#     'openInterest': '2071376.5',
#     'turnover24h': '847312.9276',
#     'volume24h': '1087473.09999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CTSIUSDT',
#     'bidPrice': '0.12810',
#     'askPrice': '0.12820',
#     'lastPrice': '0.12815',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.13180',
#     'price24hPcnt': '-0.027693',
#     'highPrice24h': '0.13335',
#     'lowPrice24h': '0.12585',
#     'prevPrice1h': '0.12715',
#     'markPrice': '0.12803',
#     'indexPrice': '0.12792',
#     'openInterest': '4868545',
#     'turnover24h': '969872.01639999',
#     'volume24h': '7432450',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CVCUSDT',
#     'bidPrice': '0.10574',
#     'askPrice': '0.10579',
#     'lastPrice': '0.10573',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.10487',
#     'price24hPcnt': '0.0082',
#     'highPrice24h': '0.10828',
#     'lowPrice24h': '0.10356',
#     'prevPrice1h': '0.10600',
#     'markPrice': '0.10573',
#     'indexPrice': '0.10581',
#     'openInterest': '8388784',
#     'turnover24h': '841126.69929',
#     'volume24h': '7972047',
#     'fundingRate': '-0.000191',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'CVXUSDT',
#     'bidPrice': '5.085',
#     'askPrice': '5.090',
#     'lastPrice': '5.085',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '4.880',
#     'price24hPcnt': '0.042008',
#     'highPrice24h': '5.145',
#     'lowPrice24h': '4.805',
#     'prevPrice1h': '5.030',
#     'markPrice': '5.083',
#     'indexPrice': '5.081',
#     'openInterest': '157593.87',
#     'turnover24h': '3933588.75564999',
#     'volume24h': '788750.77',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DARUSDT',
#     'bidPrice': '0.1555',
#     'askPrice': '0.1560',
#     'lastPrice': '0.1555',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.1570',
#     'price24hPcnt': '-0.009554',
#     'highPrice24h': '0.1700',
#     'lowPrice24h': '0.1535',
#     'prevPrice1h': '0.1550',
#     'markPrice': '0.1558',
#     'indexPrice': '0.1558',
#     'openInterest': '2396416.7',
#     'turnover24h': '1346057.43014999',
#     'volume24h': '8398499.09999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DASHUSDT',
#     'bidPrice': '49.10',
#     'askPrice': '49.15',
#     'lastPrice': '49.15',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '49.85',
#     'price24hPcnt': '-0.014042',
#     'highPrice24h': '50.40',
#     'lowPrice24h': '48.35',
#     'prevPrice1h': '49.05',
#     'markPrice': '49.12',
#     'indexPrice': '49.10',
#     'openInterest': '75859.32',
#     'turnover24h': '2648285.9715',
#     'volume24h': '53561.37999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DENTUSDT',
#     'bidPrice': '0.000867',
#     'askPrice': '0.000868',
#     'lastPrice': '0.000867',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.000883',
#     'price24hPcnt': '-0.01812',
#     'highPrice24h': '0.000918',
#     'lowPrice24h': '0.000853',
#     'prevPrice1h': '0.000864',
#     'markPrice': '0.000867',
#     'indexPrice': '0.000867',
#     'openInterest': '415575400',
#     'turnover24h': '964677.43019999',
#     'volume24h': '1084762300',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DGBUSDT',
#     'bidPrice': '0.00983',
#     'askPrice': '0.00984',
#     'lastPrice': '0.00983',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.01015',
#     'price24hPcnt': '-0.031527',
#     'highPrice24h': '0.01032',
#     'lowPrice24h': '0.00974',
#     'prevPrice1h': '0.00981',
#     'markPrice': '0.00983',
#     'indexPrice': '0.00982',
#     'openInterest': '126513170',
#     'turnover24h': '317981.93059999',
#     'volume24h': '31783380',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DODOUSDT',
#     'bidPrice': '0.12140',
#     'askPrice': '0.12150',
#     'lastPrice': '0.12140',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.11995',
#     'price24hPcnt': '0.012088',
#     'highPrice24h': '0.12525',
#     'lowPrice24h': '0.11880',
#     'prevPrice1h': '0.11960',
#     'markPrice': '0.12140',
#     'indexPrice': '0.12127',
#     'openInterest': '3764406',
#     'turnover24h': '898151.80334999',
#     'volume24h': '7391164',
#     'fundingRate': '0.000379',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DOGEUSDT',
#     'bidPrice': '0.08662',
#     'askPrice': '0.08663',
#     'lastPrice': '0.08662',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.08443',
#     'price24hPcnt': '0.025938',
#     'highPrice24h': '0.08920',
#     'lowPrice24h': '0.08260',
#     'prevPrice1h': '0.08646',
#     'markPrice': '0.08662',
#     'indexPrice': '0.08661',
#     'openInterest': '895929079',
#     'turnover24h': '162116174.40675983',
#     'volume24h': '1890374558',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DOTUSDT',
#     'bidPrice': '5.945',
#     'askPrice': '5.950',
#     'lastPrice': '5.945',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '5.995',
#     'price24hPcnt': '-0.00834',
#     'highPrice24h': '6.220',
#     'lowPrice24h': '5.865',
#     'prevPrice1h': '5.920',
#     'markPrice': '5.947',
#     'indexPrice': '5.949',
#     'openInterest': '3453625.1',
#     'turnover24h': '43289115.09149999',
#     'volume24h': '7181854.1',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DUSKUSDT',
#     'bidPrice': '0.1039',
#     'askPrice': '0.1040',
#     'lastPrice': '0.1039',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.1029',
#     'price24hPcnt': '0.009718',
#     'highPrice24h': '0.1066',
#     'lowPrice24h': '0.1015',
#     'prevPrice1h': '0.1030',
#     'markPrice': '0.1039',
#     'indexPrice': '0.1038',
#     'openInterest': '4573166',
#     'turnover24h': '684766.2453',
#     'volume24h': '6591332',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'DYDXUSDT',
#     'bidPrice': '1.400',
#     'askPrice': '1.405',
#     'lastPrice': '1.405',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '1.490',
#     'price24hPcnt': '-0.057046',
#     'highPrice24h': '1.515',
#     'lowPrice24h': '1.370',
#     'prevPrice1h': '1.385',
#     'markPrice': '1.401',
#     'indexPrice': '1.401',
#     'openInterest': '4434743.4',
#     'turnover24h': '18300766.463',
#     'volume24h': '12763897.19999998',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'EGLDUSDT',
#     'bidPrice': '41.85',
#     'askPrice': '41.90',
#     'lastPrice': '41.90',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '40.85',
#     'price24hPcnt': '0.025703',
#     'highPrice24h': '42.50',
#     'lowPrice24h': '40.50',
#     'prevPrice1h': '42.40',
#     'markPrice': '41.87',
#     'indexPrice': '41.80',
#     'openInterest': '77994.38',
#     'turnover24h': '6614725.22699999',
#     'volume24h': '158981.83',
#     'fundingRate': '0.00043',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
# ...
#     'turnover24h': '9584244.04709999',
#     'volume24h': '10013404.3',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'TLMUSDT',
#     'bidPrice': '0.016290',
#     'askPrice': '0.016300',
#     'lastPrice': '0.016295',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.016450',
#     'price24hPcnt': '-0.009422',
#     'highPrice24h': '0.016810',
#     'lowPrice24h': '0.015965',
#     'prevPrice1h': '0.016160',
#     'markPrice': '0.016290',
#     'indexPrice': '0.016272',
#     'openInterest': '25195300',
#     'turnover24h': '1308145.03931999',
#     'volume24h': '80117786',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'TOMOUSDT',
#     'bidPrice': '0.3320',
#     'askPrice': '0.3325',
#     'lastPrice': '0.3315',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.3385',
#     'price24hPcnt': '-0.020679',
#     'highPrice24h': '0.3430',
#     'lowPrice24h': '0.3275',
#     'prevPrice1h': '0.3310',
#     'markPrice': '0.3316',
#     'indexPrice': '0.3316',
#     'openInterest': '288980.8',
#     'turnover24h': '266022.65765',
#     'volume24h': '791925.2',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'TRBUSDT',
#     'bidPrice': '14.925',
#     'askPrice': '14.930',
#     'lastPrice': '14.925',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '15.510',
#     'price24hPcnt': '-0.037717',
#     'highPrice24h': '15.690',
#     'lowPrice24h': '14.635',
#     'prevPrice1h': '14.870',
#     'markPrice': '14.925',
#     'indexPrice': '14.912',
#     'openInterest': '166472.85999999',
#     'turnover24h': '2305079.62724999',
#     'volume24h': '151569.08999999',
#     'fundingRate': '0.000107',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'TRXUSDT',
#     'bidPrice': '0.06197',
#     'askPrice': '0.06198',
#     'lastPrice': '0.06199',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.06230',
#     'price24hPcnt': '-0.004975',
#     'highPrice24h': '0.06263',
#     'lowPrice24h': '0.06137',
#     'prevPrice1h': '0.06191',
#     'markPrice': '0.06199',
#     'indexPrice': '0.06202',
#     'openInterest': '94193633',
#     'turnover24h': '4285235.22017999',
#     'volume24h': '69103767',
#     'fundingRate': '-0.00007',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'TWTUSDT',
#     'bidPrice': '1.5325',
#     'askPrice': '1.5330',
#     'lastPrice': '1.5335',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '1.5645',
#     'price24hPcnt': '-0.019814',
#     'highPrice24h': '1.5715',
#     'lowPrice24h': '1.5135',
#     'prevPrice1h': '1.5290',
#     'markPrice': '1.5330',
#     'indexPrice': '1.5312',
#     'openInterest': '2607026.9',
#     'turnover24h': '3675567.24045',
#     'volume24h': '2382235.1',
#     'fundingRate': '0.000333',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'UNFIUSDT',
#     'bidPrice': '4.5745',
#     'askPrice': '4.5750',
#     'lastPrice': '4.5750',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '4.7275',
#     'price24hPcnt': '-0.032258',
#     'highPrice24h': '4.7805',
#     'lowPrice24h': '4.5005',
#     'prevPrice1h': '4.5410',
#     'markPrice': '4.5735',
#     'indexPrice': '4.5713',
#     'openInterest': '173770.6',
#     'turnover24h': '2803097.7094',
#     'volume24h': '602154.09999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'UNIUSDT',
#     'bidPrice': '6.384',
#     'askPrice': '6.385',
#     'lastPrice': '6.382',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '6.584',
#     'price24hPcnt': '-0.03068',
#     'highPrice24h': '6.657',
#     'lowPrice24h': '6.303',
#     'prevPrice1h': '6.333',
#     'markPrice': '6.383',
#     'indexPrice': '6.383',
#     'openInterest': '734168.7',
#     'turnover24h': '10903056.86910002',
#     'volume24h': '1689212.59999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'USDCUSDT',
#     'bidPrice': '1.0003',
#     'askPrice': '1.0004',
#     'lastPrice': '1.0004',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '1.0003',
#     'price24hPcnt': '0.000099',
#     'highPrice24h': '1.0004',
#     'lowPrice24h': '1.0000',
#     'prevPrice1h': '1.0004',
#     'markPrice': '1.0003',
#     'indexPrice': '0.9999',
#     'openInterest': '2100226',
#     'turnover24h': '40974.62601999',
#     'volume24h': '40965.39999999',
#     'fundingRate': '0',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'VETUSDT',
#     'bidPrice': '0.02115',
#     'askPrice': '0.02120',
#     'lastPrice': '0.02120',
#     'lastTickDirection': 'PlusTick',
#     'prevPrice24h': '0.02135',
#     'price24hPcnt': '-0.007025',
#     'highPrice24h': '0.02180',
#     'lowPrice24h': '0.02085',
#     'prevPrice1h': '0.02105',
#     'markPrice': '0.02119',
#     'indexPrice': '0.02117',
#     'openInterest': '161869923',
#     'turnover24h': '2715706.57675',
#     'volume24h': '126611563',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'WAVESUSDT',
#     'bidPrice': '2.190',
#     'askPrice': '2.195',
#     'lastPrice': '2.195',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '2.315',
#     'price24hPcnt': '-0.051835',
#     'highPrice24h': '2.375',
#     'lowPrice24h': '2.125',
#     'prevPrice1h': '2.160',
#     'markPrice': '2.192',
#     'indexPrice': '2.190',
#     'openInterest': '2074920.6',
#     'turnover24h': '19793575.99050001',
#     'volume24h': '8785690.1',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'WOOUSDT',
#     'bidPrice': '0.1875',
#     'askPrice': '0.1876',
#     'lastPrice': '0.1876',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.1973',
#     'price24hPcnt': '-0.049163',
#     'highPrice24h': '0.2026',
#     'lowPrice24h': '0.1845',
#     'prevPrice1h': '0.1862',
#     'markPrice': '0.1876',
#     'indexPrice': '0.1875',
#     'openInterest': '5967071.5',
#     'turnover24h': '5595876.91869',
#     'volume24h': '28699829.80000002',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XCNUSDT',
#     'bidPrice': '0.01217',
#     'askPrice': '0.01218',
#     'lastPrice': '0.01218',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.01216',
#     'price24hPcnt': '0.001644',
#     'highPrice24h': '0.01249',
#     'lowPrice24h': '0.01204',
#     'prevPrice1h': '0.01216',
#     'markPrice': '0.01218',
#     'indexPrice': '0.01215',
#     'openInterest': '43562440',
#     'turnover24h': '496374.32509999',
#     'volume24h': '40450070',
#     'fundingRate': '0.001271',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XEMUSDT',
#     'bidPrice': '0.0361',
#     'askPrice': '0.0362',
#     'lastPrice': '0.0362',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.0371',
#     'price24hPcnt': '-0.024258',
#     'highPrice24h': '0.0380',
#     'lowPrice24h': '0.0357',
#     'prevPrice1h': '0.0359',
#     'markPrice': '0.0362',
#     'indexPrice': '0.0362',
#     'openInterest': '23531383',
#     'turnover24h': '787087.1877',
#     'volume24h': '21213450',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XLMUSDT',
#     'bidPrice': '0.08765',
#     'askPrice': '0.08770',
#     'lastPrice': '0.08770',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.08765',
#     'price24hPcnt': '0.00057',
#     'highPrice24h': '0.08845',
#     'lowPrice24h': '0.08620',
#     'prevPrice1h': '0.08710',
#     'markPrice': '0.08770',
#     'indexPrice': '0.08766',
#     'openInterest': '39899862',
#     'turnover24h': '1570833.67289999',
#     'volume24h': '17949879',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XMRUSDT',
#     'bidPrice': '172.65',
#     'askPrice': '172.70',
#     'lastPrice': '172.65',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '171.95',
#     'price24hPcnt': '0.00407',
#     'highPrice24h': '174.90',
#     'lowPrice24h': '170.65',
#     'prevPrice1h': '172.10',
#     'markPrice': '172.65',
#     'indexPrice': '172.67',
#     'openInterest': '34555.76',
#     'turnover24h': '3005753.93699999',
#     'volume24h': '17378.99',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XNOUSDT',
#     'bidPrice': '0.7604',
#     'askPrice': '0.7612',
#     'lastPrice': '0.7605',
#     'lastTickDirection': 'MinusTick',
#     'prevPrice24h': '0.7793',
#     'price24hPcnt': '-0.024124',
#     'highPrice24h': '0.7900',
#     'lowPrice24h': '0.7522',
#     'prevPrice1h': '0.7607',
#     'markPrice': '0.7605',
#     'indexPrice': '0.7607',
#     'openInterest': '718060',
#     'turnover24h': '1583510.7617',
#     'volume24h': '2052011',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XRPPERP',
#     'bidPrice': '0.3909',
#     'askPrice': '0.3913',
#     'lastPrice': '0.3912',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.3885',
#     'price24hPcnt': '0.006949',
#     'highPrice24h': '0.3980',
#     'lowPrice24h': '0.3843',
#     'prevPrice1h': '0.3911',
#     'markPrice': '0.3911',
#     'indexPrice': '0.3910',
#     'openInterest': '2606344',
#     'turnover24h': '209181.6588',
#     'volume24h': '537930',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XRPUSDT',
#     'bidPrice': '0.3909',
#     'askPrice': '0.3910',
#     'lastPrice': '0.3910',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.3890',
#     'price24hPcnt': '0.005141',
#     'highPrice24h': '0.3987',
#     'lowPrice24h': '0.3834',
#     'prevPrice1h': '0.3911',
#     'markPrice': '0.3910',
#     'indexPrice': '0.3910',
#     'openInterest': '134262982',
#     'turnover24h': '129790760.63199972',
#     'volume24h': '333494212',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'XTZUSDT',
#     'bidPrice': '1.016',
#     'askPrice': '1.017',
#     'lastPrice': '1.017',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '1.041',
#     'price24hPcnt': '-0.023054',
#     'highPrice24h': '1.064',
#     'lowPrice24h': '0.996',
#     'prevPrice1h': '1.005',
#     'markPrice': '1.017',
#     'indexPrice': '1.017',
#     'openInterest': '1934418',
#     'turnover24h': '4135415.8484',
#     'volume24h': '4014257.39999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'YFIUSDT',
#     'bidPrice': '7210',
#     'askPrice': '7215',
#     'lastPrice': '7205',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '7175',
#     'price24hPcnt': '0.004181',
#     'highPrice24h': '7280',
#     'lowPrice24h': '7040',
#     'prevPrice1h': '7190',
#     'markPrice': '7207',
#     'indexPrice': '7207',
#     'openInterest': '269.3',
#     'turnover24h': '1466613.3785',
#     'volume24h': '204.4952',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'YGGUSDT',
#     'bidPrice': '0.237',
#     'askPrice': '0.238',
#     'lastPrice': '0.237',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.249',
#     'price24hPcnt': '-0.048192',
#     'highPrice24h': '0.253',
#     'lowPrice24h': '0.232',
#     'prevPrice1h': '0.235',
#     'markPrice': '0.237',
#     'indexPrice': '0.237',
#     'openInterest': '1133894.89999999',
#     'turnover24h': '682944.75279999',
#     'volume24h': '2817078.8',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ZECUSDT',
#     'bidPrice': '44.75',
#     'askPrice': '44.80',
#     'lastPrice': '44.80',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '43.50',
#     'price24hPcnt': '0.029885',
#     'highPrice24h': '45.45',
#     'lowPrice24h': '42.80',
#     'prevPrice1h': '44.35',
#     'markPrice': '44.75',
#     'indexPrice': '44.73',
#     'openInterest': '24674.92',
#     'turnover24h': '3544901.0175',
#     'volume24h': '79693.84999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ZENUSDT',
#     'bidPrice': '10.50',
#     'askPrice': '10.55',
#     'lastPrice': '10.50',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '10.65',
#     'price24hPcnt': '-0.014084',
#     'highPrice24h': '10.90',
#     'lowPrice24h': '10.30',
#     'prevPrice1h': '10.40',
#     'markPrice': '10.51',
#     'indexPrice': '10.52',
#     'openInterest': '139751.1',
#     'turnover24h': '721464.81999999',
#     'volume24h': '67904.59999999',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ZILUSDT',
#     'bidPrice': '0.02639',
#     'askPrice': '0.02640',
#     'lastPrice': '0.02639',
#     'lastTickDirection': 'ZeroMinusTick',
#     'prevPrice24h': '0.02807',
#     'price24hPcnt': '-0.05985',
#     'highPrice24h': '0.02842',
#     'lowPrice24h': '0.02593',
#     'prevPrice1h': '0.02618',
#     'markPrice': '0.02639',
#     'indexPrice': '0.02637',
#     'openInterest': '211052080',
#     'turnover24h': '11117838.4686',
#     'volume24h': '408453880',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'},
#    {'symbol': 'ZRXUSDT',
#     'bidPrice': '0.2158',
#     'askPrice': '0.2159',
#     'lastPrice': '0.2158',
#     'lastTickDirection': 'ZeroPlusTick',
#     'prevPrice24h': '0.2073',
#     'price24hPcnt': '0.041003',
#     'highPrice24h': '0.2221',
#     'lowPrice24h': '0.2064',
#     'prevPrice1h': '0.2142',
#     'markPrice': '0.2157',
#     'indexPrice': '0.2157',
#     'openInterest': '2241724',
#     'turnover24h': '1368177.40769999',
#     'volume24h': '6396342',
#     'fundingRate': '0.0001',
#     'nextFundingTime': '1674057600000',
#     'predictedDeliveryPrice': '',
#     'basisRate': '',
#     'deliveryFeeRate': '',
#     'deliveryTime': '0'}]},
#  'retExtInfo': {},
#  'time': 1674045774400}

# %%
instruments_info_response
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': '10000NFTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '10000NFT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1643007175000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000005',
#      'maxPrice': '9.999990',
#      'tickSize': '0.000005'},
#     'lotSizeFilter': {'maxTradingQty': '370000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '3700000',
#      'maxOrderQty': '370000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000BONKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000BONK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1672971039000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '8000000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '40000000',
#      'maxOrderQty': '8000000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000BTTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000BTT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1645769298000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '1860000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '18600000',
#      'maxOrderQty': '1860000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000LUNCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000LUNC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1662681601000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '30000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '300000',
#      'maxOrderQty': '30000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000XECUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000XEC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649820036000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '140000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '1400000',
#      'maxOrderQty': '140000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1INCHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1INCH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638748800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '17000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '170000.0',
#      'maxOrderQty': '17000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AAVEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AAVE',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '440.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '4400.00',
#      'maxOrderQty': '440.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ACHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ACH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649405257000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '230000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '2300000',
#      'maxOrderQty': '230000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ADAPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ADA',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '70000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '350000',
#      'maxOrderQty': '70000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'ADAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ADA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1610668800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '570000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '5700000',
#      'maxOrderQty': '570000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AGLDUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AGLD',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650608721000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '4000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '40000.0',
#      'maxOrderQty': '4000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AKROUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AKRO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1653462381000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '630000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '6300000',
#      'maxOrderQty': '630000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALGOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALGO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1632355200000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '140000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '1400000.0',
#      'maxOrderQty': '140000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALICEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALICE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '9500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '95000.0',
#      'maxOrderQty': '9500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALPHAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALPHA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648626100000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '43000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '430000',
#      'maxOrderQty': '43000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ANKRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ANKR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '180000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1800000',
#      'maxOrderQty': '180000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ANTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ANT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639672939000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '1900.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '19000.0',
#      'maxOrderQty': '1900.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'APEPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APE',
#     'quoteCoin': 'USD',
#     'launchTime': '1661990400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '4000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '20000.0',
#      'maxOrderQty': '4000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'APEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1647571477000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'API3USDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'API3',
#     'quoteCoin': 'USDT',
#     'launchTime': '1646019009000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '2800.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '28000.0',
#      'maxOrderQty': '2800.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'APTPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APT',
#     'quoteCoin': 'USD',
#     'launchTime': '1666763965000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '15000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '75000.00',
#      'maxOrderQty': '15000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'APTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1666107272000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '7900.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '79000.00',
#      'maxOrderQty': '7900.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ARPAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ARPA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650369703000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '150000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '1500000',
#      'maxOrderQty': '150000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ARUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639978762000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.01',
#      'maxPrice': '19999.98',
#      'tickSize': '0.01'},
#     'lotSizeFilter': {'maxTradingQty': '1100.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '11000.0',
#      'maxOrderQty': '1100.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ASTRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ASTR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649044122000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '33000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '330000',
#      'maxOrderQty': '33000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ATOMPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ATOM',
#     'quoteCoin': 'USD',
#     'launchTime': '1663757456000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '3500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '17500.0',
#      'maxOrderQty': '3500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'ATOMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ATOM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633910400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '12000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '120000.0',
#      'maxOrderQty': '12000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AUDIOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AUDIO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637884800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '25000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '250000.0',
#      'maxOrderQty': '25000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AVAXPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AVAX',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '2000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '10000.00',
#      'maxOrderQty': '2000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'AVAXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AVAX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1631664000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '7700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '77000.0',
#      'maxOrderQty': '7700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AXSUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AXS',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '5500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '55000.0',
#      'maxOrderQty': '5500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BAKEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAKE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648794979000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '17000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '170000.0',
#      'maxOrderQty': '17000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BALUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649405651000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '1400.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '14000.00',
#      'maxOrderQty': '1400.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BANDUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAND',
#     'quoteCoin': 'USDT',
#     'launchTime': '1645167116000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '25000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '250000.0',
#      'maxOrderQty': '25000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BATUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '23000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '230000.0',
#      'maxOrderQty': '23000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BCHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BCH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1514764800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '600.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '6000.00',
#      'maxOrderQty': '600.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BELUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BEL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1655445585000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '18000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '180000',
#      'maxOrderQty': '18000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BICOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BICO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638445217000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '1500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '15000.0',
#      'maxOrderQty': '1500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BITUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BIT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633910400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '82000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '820000.0',
#      'maxOrderQty': '82000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BLZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BLZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1654497673000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '83000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '830000',
#      'maxOrderQty': '83000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BNBPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNB',
#     'quoteCoin': 'USD',
#     'launchTime': '1664459242000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '1000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '5000.00',
#      'maxOrderQty': '1000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'BNBUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNB',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '1000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '10000.00',
#      'maxOrderQty': '1000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BNXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649229152000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '105.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1050.00',
#      'maxOrderQty': '105.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BOBAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BOBA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649231761000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '3300.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '33000.0',
#      'maxOrderQty': '3300.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BSVUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BSV',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639105708000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '60.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '600.00',
#      'maxOrderQty': '60.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BSWUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BSW',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648017126000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '26000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '260000',
#      'maxOrderQty': '26000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BTCPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USD',
#     'launchTime': '1610604231000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '125.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.50',
#      'maxPrice': '999999.00',
#      'tickSize': '0.50'},
#     'lotSizeFilter': {'maxTradingQty': '20.000',
#      'minTradingQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '100.000',
#      'maxOrderQty': '20.000',
#      'minOrderQty': '0.001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'BTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1584230400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '100.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.50',
#      'maxPrice': '999999.00',
#      'tickSize': '0.50'},
#     'lotSizeFilter': {'maxTradingQty': '100.000',
#      'minTradingQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '1000.000',
#      'maxOrderQty': '100.000',
#      'minOrderQty': '0.001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'C98USDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'C98',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CEEKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CEEK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1658127698000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '13000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '130000',
#      'maxOrderQty': '13000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CELOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CELO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1641367582000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '8700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '87000.0',
#      'maxOrderQty': '8700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CELRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CELR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '490000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '4900000',
#      'maxOrderQty': '490000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CHRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637193600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '42000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '420000.0',
#      'maxOrderQty': '42000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CHZPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHZ',
#     'quoteCoin': 'USD',
#     'launchTime': '1663815035000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '150000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '750000',
#      'maxOrderQty': '150000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'CHZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633996800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '350000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '3500000',
#      'maxOrderQty': '350000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CKBUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CKB',
#     'quoteCoin': 'USDT',
#     'launchTime': '1644901148000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000005',
#      'maxPrice': '9.999990',
#      'tickSize': '0.000005'},
#     'lotSizeFilter': {'maxTradingQty': '370000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '3700000',
#      'maxOrderQty': '370000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'COMPUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'COMP',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '270.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '2700.00',
#      'maxOrderQty': '270.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'COTIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'COTI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638445117000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '91000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '910000',
#      'maxOrderQty': '91000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CREAMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CREAM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1642405767000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '70.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '700.00',
#      'maxOrderQty': '70.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CROUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CRO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637625600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '120000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1200000',
#      'maxOrderQty': '120000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CRVUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CRV',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '35000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '350000.0',
#      'maxOrderQty': '35000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1652774270000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '690',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '6900',
#      'maxOrderQty': '690',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638444847000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '8600.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '86000.0',
#      'maxOrderQty': '8600.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTSIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTSI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648018511000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '39000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '390000',
#      'maxOrderQty': '39000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CVCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CVC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638285651000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '61000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '610000',
#      'maxOrderQty': '61000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CVXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CVX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650440282000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
# ...
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '1100000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '11000000',
#      'maxOrderQty': '1100000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'TWTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'TWT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1668666261000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '10000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '100000.0',
#      'maxOrderQty': '10000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'UNFIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'UNFI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1653899789000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '4700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '47000.0',
#      'maxOrderQty': '4700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'UNIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'UNI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638230400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '6700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '67000.0',
#      'maxOrderQty': '6700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'USDCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'USDC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1656399612000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '50000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '500000.0',
#      'maxOrderQty': '50000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'VETUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'VET',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '640000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '6400000',
#      'maxOrderQty': '640000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'WAVESUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'WAVES',
#     'quoteCoin': 'USDT',
#     'launchTime': '1641368026000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '4900.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '49000.0',
#      'maxOrderQty': '4900.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'WOOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'WOO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1636416000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '44000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '440000.0',
#      'maxOrderQty': '44000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XCNUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XCN',
#     'quoteCoin': 'USDT',
#     'launchTime': '1651132431000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '18000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '180000',
#      'maxOrderQty': '18000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XEMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XEM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638252824000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '210000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '2100000',
#      'maxOrderQty': '210000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XLMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XLM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '250000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '2500000',
#      'maxOrderQty': '250000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XMRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XMR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1640143015000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '140.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1400.00',
#      'maxOrderQty': '140.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XNOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XNO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1662076800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '4200',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '42000',
#      'maxOrderQty': '4200',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XRPPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XRP',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '350000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1750000',
#      'maxOrderQty': '350000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'XRPUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XRP',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '2100000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '21000000',
#      'maxOrderQty': '2100000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XTZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XTZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1514764800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'YFIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'YFI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638930769000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '0',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '5', 'maxPrice': '9999990', 'tickSize': '5'},
#     'lotSizeFilter': {'maxTradingQty': '1.0000',
#      'minTradingQty': '0.0001',
#      'qtyStep': '0.0001',
#      'postOnlyMaxOrderQty': '10.0000',
#      'maxOrderQty': '1.0000',
#      'minOrderQty': '0.0001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'YGGUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'YGG',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637625600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '7400.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '74000.0',
#      'maxOrderQty': '7400.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZECUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZEC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '180.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1800.00',
#      'maxOrderQty': '180.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZENUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZEN',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637884800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '440.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '4400.0',
#      'maxOrderQty': '440.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZILUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZIL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1643480306000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '790000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '7900000',
#      'maxOrderQty': '790000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZRXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZRX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648453878000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '35000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '350000',
#      'maxOrderQty': '35000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'}],
#   'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1674045774677}

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## Transform data

# %%
coins_info = transform_data(tickers_response, instruments_info_response)

coins_info
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 0    10000NFTUSDT     -0.002152  1.614310e+07     0.000100  6.435063e+07
# 1    1000BONKUSDT     -0.033358  1.446830e+10     0.000721  1.037650e+10
# 2     1000BTTUSDT      0.009575  1.622560e+08     0.000100  3.768068e+08
# 3    1000LUNCUSDT     -0.014037  2.674891e+07     0.000100  1.760096e+07
# 4     1000XECUSDT      0.030293  6.085542e+07     0.000100  4.775320e+06
# ..            ...           ...           ...          ...           ...
# 200       YGGUSDT     -0.048192  2.817079e+06     0.000100  1.133895e+06
# 201       ZECUSDT      0.029885  7.969385e+04     0.000100  2.467492e+04
# 202       ZENUSDT     -0.014084  6.790460e+04     0.000100  1.397511e+05
# 203       ZILUSDT     -0.059850  4.084539e+08     0.000100  2.110521e+08
# 204       ZRXUSDT      0.041003  6.396342e+06     0.000100  2.241724e+06
#
#              launchTime
# 0   2022-01-24 07:52:55
# 1   2023-01-06 03:10:39
# 2   2022-02-25 07:08:18
# 3   2022-09-09 02:00:01
# 4   2022-04-13 05:20:36
# ..                  ...
# 200 2021-11-23 01:00:00
# 201 2021-11-24 01:00:00
# 202 2021-11-26 01:00:00
# 203 2022-01-29 19:18:26
# 204 2022-03-28 09:51:18
#
# [205 rows x 6 columns]

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## Report data

# %% [markdown]
# ### Most traded by 24h volume

# %%
coins_info.sort_values(by="volume24h", ascending=False).head(10)
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 163  SHIB1000USDT      0.165094  1.759066e+10     0.000100  1.245206e+09
# 1    1000BONKUSDT     -0.033358  1.446830e+10     0.000721  1.037650e+10
# 91       GALAUSDT     -0.078514  5.262387e+09     0.000100  5.070275e+08
# 169     SPELLUSDT     -0.006963  2.239758e+09     0.000100  7.414602e+08
# 71       DOGEUSDT      0.025938  1.890375e+09     0.000100  8.959291e+08
# 101       HOTUSDT     -0.035784  1.602883e+09     0.000100  5.557512e+08
# 68       DENTUSDT     -0.018120  1.084762e+09     0.000100  4.155754e+08
# 149      REEFUSDT      0.008264  8.185446e+08     0.000100  2.409659e+08
# 7         ACHUSDT     -0.064837  5.895454e+08     0.000137  9.897062e+07
# 110     JASMYUSDT     -0.061271  4.895890e+08     0.000100  2.171158e+08
#
#              launchTime
# 163 2021-10-20 02:00:00
# 1   2023-01-06 03:10:39
# 91  2021-11-09 01:00:00
# 169 2021-12-13 02:21:09
# 71  1970-01-01 01:00:00
# 101 2022-03-28 08:49:16
# 68  2022-01-13 11:15:28
# 149 2022-02-15 01:30:00
# 7   2022-04-08 10:07:37
# 110 2022-01-19 07:36:42

# %% [markdown]
# ### Biggest Gainers

# %%
coins_info.sort_values(by="price24hPcnt", ascending=False).head(10)
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 92        GALUSDT      0.166134  2.348708e+07    -0.006705  2.391028e+06
# 163  SHIB1000USDT      0.165094  1.759066e+10     0.000100  1.245206e+09
# 76        ENJUSDT      0.103542  1.544898e+07    -0.001217  6.085352e+06
# 49       CEEKUSDT      0.058354  1.740631e+07     0.000171  3.382141e+06
# 84       ETHWUSDT      0.057441  2.469874e+06     0.000510  7.425005e+05
# 60        CRVUSDT      0.043333  4.580233e+07     0.000100  7.274125e+06
# 65        CVXUSDT      0.042008  7.887508e+05     0.000100  1.575939e+05
# 204       ZRXUSDT      0.041003  6.396342e+06     0.000100  2.241724e+06
# 178       SXPUSDT      0.039697  6.951255e+06     0.000100  4.940980e+06
# 102       ICPUSDT      0.036468  3.716417e+06     0.000100  6.874174e+05
#
#              launchTime
# 92  2022-05-05 16:01:18
# 163 2021-10-20 02:00:00
# 76  2021-10-31 17:00:00
# 49  2022-07-18 09:01:38
# 84  2022-09-16 02:00:00
# 60  2021-10-25 02:00:00
# 65  2022-04-20 09:38:02
# 204 2022-03-28 09:51:18
# 178 2021-12-08 04:01:21
# 102 2021-09-15 02:00:00

# %% [markdown]
# ### Biggest Lossers

# %%
coins_info.sort_values(by="price24hPcnt", ascending=True).head(10)
# Out:
#         symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 90     FXSUSDT     -0.088088  2.356405e+06     0.000742  7.765005e+05
# 91    GALAUSDT     -0.078514  5.262387e+09     0.000100  5.070275e+08
# 10    AGLDUSDT     -0.072485  1.303046e+06     0.000100  4.277880e+05
# 105    IMXUSDT     -0.069875  2.823371e+06     0.000100  7.776776e+05
# 128  MAGICUSDT     -0.069810  1.627235e+07     0.000100  3.141649e+06
# 13   ALICEUSDT     -0.069182  2.781479e+06     0.000100  6.487567e+05
# 55     CKBUSDT     -0.068713  4.764302e+07     0.000100  7.102908e+07
# 7      ACHUSDT     -0.064837  5.895454e+08     0.000137  9.897062e+07
# 122  LOOKSUSDT     -0.063567  1.567121e+07     0.000353  5.717279e+06
# 110  JASMYUSDT     -0.061271  4.895890e+08     0.000100  2.171158e+08
#
#              launchTime
# 90  2022-04-04 06:00:20
# 91  2021-11-09 01:00:00
# 10  2022-04-22 08:25:21
# 105 2021-11-24 01:00:00
# 128 2022-12-13 03:18:41
# 13  2021-10-25 02:00:00
# 55  2022-02-15 05:59:08
# 7   2022-04-08 10:07:37
# 122 2022-01-24 07:37:12
# 110 2022-01-19 07:36:42

# %% [markdown]
# ### Top New Listing Coins

# %%
coins_info.sort_values(by="launchTime", ascending=False).head(10)
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 1    1000BONKUSDT     -0.033358  1.446830e+10     0.000721  1.037650e+10
# 128     MAGICUSDT     -0.069810  1.627235e+07     0.000100  3.141649e+06
# 184       TWTUSDT     -0.019814  2.382235e+06     0.000333  2.607027e+06
# 177     SWEATUSDT     -0.005016  6.458451e+07     0.000100  6.264989e+07
# 20        APTPERP     -0.054522  1.053635e+05     0.000100  5.558564e+04
# 21        APTUSDT     -0.054489  1.788727e+07     0.000100  2.636775e+06
# 96        GMXUSDT     -0.003318  4.974220e+04     0.000500  6.836927e+04
# 126     LUNA2PERP     -0.021894  6.822620e+04     0.000100  1.223270e+05
# 117       LDOPERP      0.008687  7.822500e+04     0.000100  7.439740e+04
# 40        BNBPERP     -0.004298  1.475310e+03     0.000100  3.441860e+03
#
#              launchTime
# 1   2023-01-06 03:10:39
# 128 2022-12-13 03:18:41
# 184 2022-11-17 07:24:21
# 177 2022-11-03 16:10:53
# 20  2022-10-26 07:59:25
# 21  2022-10-18 17:34:32
# 96  2022-10-10 09:06:10
# 126 2022-09-29 17:07:36
# 117 2022-09-29 17:01:19
# 40  2022-09-29 15:47:22

# %% [markdown]
# ### Biggest Open Interest

# %%
coins_info.sort_values(by="openInterest", ascending=False).head(10)
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 1    1000BONKUSDT     -0.033358  1.446830e+10     0.000721  1.037650e+10
# 163  SHIB1000USDT      0.165094  1.759066e+10     0.000100  1.245206e+09
# 71       DOGEUSDT      0.025938  1.890375e+09     0.000100  8.959291e+08
# 169     SPELLUSDT     -0.006963  2.239758e+09     0.000100  7.414602e+08
# 101       HOTUSDT     -0.035784  1.602883e+09     0.000100  5.557512e+08
# 91       GALAUSDT     -0.078514  5.262387e+09     0.000100  5.070275e+08
# 68       DENTUSDT     -0.018120  1.084762e+09     0.000100  4.155754e+08
# 2     1000BTTUSDT      0.009575  1.622560e+08     0.000100  3.768068e+08
# 154       RSRUSDT     -0.010032  4.570172e+08     0.000100  2.621785e+08
# 149      REEFUSDT      0.008264  8.185446e+08     0.000100  2.409659e+08
#
#              launchTime
# 1   2023-01-06 03:10:39
# 163 2021-10-20 02:00:00
# 71  1970-01-01 01:00:00
# 169 2021-12-13 02:21:09
# 101 2022-03-28 08:49:16
# 91  2021-11-09 01:00:00
# 68  2022-01-13 11:15:28
# 2   2022-02-25 07:08:18
# 154 2021-11-30 16:28:21
# 149 2022-02-15 01:30:00

# %% [markdown]
# ### Biggest positive funding fee

# %%
coins_info.sort_values(by="fundingRate", ascending=False).head(10)
# Out:
#            symbol  price24hPcnt     volume24h  fundingRate  openInterest  \
# 191       XCNUSDT      0.001644  4.045007e+07     0.001271  4.356244e+07
# 90        FXSUSDT     -0.088088  2.356405e+06     0.000742  7.765005e+05
# 1    1000BONKUSDT     -0.033358  1.446830e+10     0.000721  1.037650e+10
# 11       AKROUSDT     -0.031001  2.642339e+08     0.000690  1.910623e+08
# 50       CELOUSDT     -0.045519  1.210766e+07     0.000543  1.393806e+06
# 145        OPUSDT     -0.057251  4.600952e+07     0.000530  8.824636e+06
# 84       ETHWUSDT      0.057441  2.469874e+06     0.000510  7.425005e+05
# 96        GMXUSDT     -0.003318  4.974220e+04     0.000500  6.836927e+04
# 61        CTCUSDT     -0.016383  1.627611e+06     0.000447  7.530100e+05
# 75       EGLDUSDT      0.025703  1.589818e+05     0.000430  7.799438e+04
#
#              launchTime
# 191 2022-04-28 09:53:51
# 90  2022-04-04 06:00:20
# 1   2023-01-06 03:10:39
# 11  2022-05-25 09:06:21
# 50  2022-01-05 08:26:22
# 145 2022-06-01 06:51:03
# 84  2022-09-16 02:00:00
# 96  2022-10-10 09:06:10
# 61  2022-05-17 09:57:50
# 75  2021-11-22 17:00:00

# %% [markdown]
# ### Biggest negative funding fee

# %%
coins_info.sort_values(by="fundingRate", ascending=True).head(10)
# Out:
#        symbol  price24hPcnt    volume24h  fundingRate  openInterest  \
# 92    GALUSDT      0.166134  23487078.85    -0.006705  2.391028e+06
# 43   BOBAUSDT      0.004761   1333806.00    -0.002418  5.443962e+05
# 76    ENJUSDT      0.103542  15448982.80    -0.001217  6.085352e+06
# 151   REQUSDT     -0.039399   2767227.00    -0.000814  2.590713e+06
# 18    APEUSDT     -0.039515  10056542.80    -0.000791  3.886144e+06
# 17    APEPERP     -0.039149     54749.70    -0.000753  1.029638e+05
# 93   GLMRUSDT      0.017283   3134503.90    -0.000204  3.096262e+06
# 64    CVCUSDT      0.008200   7972047.00    -0.000191  8.388784e+06
# 59    CROUSDT     -0.022900  36207579.00    -0.000190  4.737410e+07
# 47    BTCUSDT     -0.001012    149570.97    -0.000076  5.521130e+04
#
#              launchTime
# 92  2022-05-05 16:01:18
# 43  2022-04-06 09:56:01
# 76  2021-10-31 17:00:00
# 151 2021-12-06 01:00:00
# 18  2022-03-18 03:44:37
# 17  2022-09-01 02:00:00
# 93  2022-03-30 11:40:50
# 64  2021-11-30 16:20:51
# 59  2021-11-23 01:00:00
# 47  2020-03-15 01:00:00
