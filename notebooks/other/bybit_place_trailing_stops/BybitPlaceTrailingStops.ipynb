# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="resources/bybit_logo.png"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Bybit place trailing stops
#
# Application for set trailing stop for open position if it has not been set up yet on Bybit futures cryptocurrency exchanges.

# %% [markdown]
# ![purple-divider](resources/purple_divider.png)
#
# ## Hands on!

# %%
import pandas as pd
import requests
from pybit import usdt_perpetual
from utils import load_config, transform_positions, place_trailing_stops, parse_active_positions

config = load_config("../../../config.yaml")

exchange = usdt_perpetual.HTTP(
    endpoint = config["bybitApi"]["endpoint"],
    api_key = config["bybitApi"]["apiKey"],
    api_secret = config["bybitApi"]["secretKey"]
)

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
# ## Loading data

# %%
positions_raw = exchange.my_position()

instruments_info = requests.get(config["bybitApi"]["instrumentInfoEndpoint"]).json()

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## The data at a glance

# %%
positions_raw
# Out:
# {'ret_code': 0,
#  'ret_msg': 'OK',
#  'result': [{'data': {'user_id': 49436126,
#     'symbol': '10000NFTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': '1000BONKUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 2.29,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 11.95252574,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': '1000BTTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': '1000LUNCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': '1000XECUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': '1INCHUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1466,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AAVEUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 191,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ACHUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ADAUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 116,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AGLDUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AKROUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ALGOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 4.48,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 596,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ALICEUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 866,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ALPHAUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ANKRUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1121,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ANTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1526,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'APEUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'API3USDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'APTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 8.12,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ARPAUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ARUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1556,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ASTRUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ATOMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 6.24,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 431,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AUDIOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1256,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AVAXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 446,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'AXSUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 371,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BAKEUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BALUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BANDUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BATUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1061,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BCHUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 56,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BELUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BICOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1451,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BITUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 716,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BLZUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BNBUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 251,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BNXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BOBAUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BSVUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 551,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BSWUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'BTCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 7.34,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'C98USDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 806,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CEEKUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CELOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 3.49,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': -22.45960521,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1646,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CELRUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 761,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CHRUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1046,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CHZUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 461,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CKBUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'COMPUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 356,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'COTIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 851,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CREAMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CROUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1166,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CRVUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 2.46,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 19.97737836,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 476,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CTCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CTKUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1436,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CTSIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CVCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1346,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'CVXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DARUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DASHUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 686,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DENTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DGBUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DODOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DOGEUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 7.26,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 206,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DOTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 131,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DUSKUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1541,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'DYDXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 3.11,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 611,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'EGLDUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 881,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ENJUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 491,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ENSUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 7.78,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1016,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'EOSUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 26,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ETCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 236,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ETHUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 11,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ETHWUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'FILUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 5,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 18.406608,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 266,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'FITFIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'FLMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'FLOWUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
# ...
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1181,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'THETAUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 341,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'TLMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 926,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'TOMOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'TRBUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'TRXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 311,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'TWTUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'UNFIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'UNIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 146,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'USDCUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'VETUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 326,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'WAVESUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1661,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'WOOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 2.93,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 986,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XCNUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XEMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 161,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XLMUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 296,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XMRUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 9.41,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1586,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XNOUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XRPUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 41,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'XTZUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 86,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'YFIUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 2.25,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 536,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'YGGUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1196,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ZECUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 4.32,
#     'auto_add_margin': 0,
#     'is_isolated': True,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1211,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ZENUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1271,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ZILUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True},
#   {'data': {'user_id': 49436126,
#     'symbol': 'ZRXUSDT',
#     'side': 'None',
#     'size': 0,
#     'position_value': 0,
#     'entry_price': 0,
#     'liq_price': 0,
#     'bust_price': 0,
#     'leverage': 10,
#     'auto_add_margin': 0,
#     'is_isolated': False,
#     'position_margin': 0,
#     'occ_closing_fee': 0,
#     'realised_pnl': 0,
#     'cum_realised_pnl': 0,
#     'free_qty': 0,
#     'tp_sl_mode': 'Full',
#     'unrealised_pnl': 0,
#     'deleverage_indicator': 0,
#     'risk_id': 1,
#     'stop_loss': 0,
#     'take_profit': 0,
#     'trailing_stop': 0,
#     'position_idx': 0,
#     'mode': 'MergedSingle'},
#    'is_valid': True}],
#  'ext_code': '',
#  'ext_info': '',
#  'time_now': '1674896451.489056',
#  'rate_limit_status': 117,
#  'rate_limit': 120,
#  'rate_limit_reset_ms': 1674896451485}

# %%
instruments_info
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': '10000NFTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '10000NFT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1643007175000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000005',
#      'maxPrice': '9.999990',
#      'tickSize': '0.000005'},
#     'lotSizeFilter': {'maxTradingQty': '370000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '3700000',
#      'maxOrderQty': '370000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000BONKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000BONK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1672971039000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '8000000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '40000000',
#      'maxOrderQty': '8000000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000BTTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000BTT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1645769298000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '1860000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '18600000',
#      'maxOrderQty': '1860000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000LUNCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000LUNC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1662681601000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '30000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '300000',
#      'maxOrderQty': '30000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1000XECUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1000XEC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649820036000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '140000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '1400000',
#      'maxOrderQty': '140000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': '1INCHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': '1INCH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638748800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '17000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '170000.0',
#      'maxOrderQty': '17000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AAVEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AAVE',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '440.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '4400.00',
#      'maxOrderQty': '440.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ACHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ACH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649405257000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '230000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '2300000',
#      'maxOrderQty': '230000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ADAPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ADA',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '70000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '350000',
#      'maxOrderQty': '70000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'ADAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ADA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1610668800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '570000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '5700000',
#      'maxOrderQty': '570000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AGLDUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AGLD',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650608721000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '4000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '40000.0',
#      'maxOrderQty': '4000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AKROUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AKRO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1653462381000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000001',
#      'maxPrice': '1.999998',
#      'tickSize': '0.000001'},
#     'lotSizeFilter': {'maxTradingQty': '630000',
#      'minTradingQty': '100',
#      'qtyStep': '100',
#      'postOnlyMaxOrderQty': '6300000',
#      'maxOrderQty': '630000',
#      'minOrderQty': '100'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALGOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALGO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1632355200000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '140000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '1400000.0',
#      'maxOrderQty': '140000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALICEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALICE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '9500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '95000.0',
#      'maxOrderQty': '9500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ALPHAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ALPHA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648626100000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '43000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '430000',
#      'maxOrderQty': '43000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ANKRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ANKR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '180000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1800000',
#      'maxOrderQty': '180000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ANTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ANT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639672939000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '1900.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '19000.0',
#      'maxOrderQty': '1900.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'APEPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APE',
#     'quoteCoin': 'USD',
#     'launchTime': '1661990400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '4000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '20000.0',
#      'maxOrderQty': '4000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'APEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1647571477000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'API3USDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'API3',
#     'quoteCoin': 'USDT',
#     'launchTime': '1646019009000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '2800.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '28000.0',
#      'maxOrderQty': '2800.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'APTPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APT',
#     'quoteCoin': 'USD',
#     'launchTime': '1666763965000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '15000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '75000.00',
#      'maxOrderQty': '15000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'APTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'APT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1666107272000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '7900.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '79000.00',
#      'maxOrderQty': '7900.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ARPAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ARPA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650369703000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '150000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '1500000',
#      'maxOrderQty': '150000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ARUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639978762000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.01',
#      'maxPrice': '19999.98',
#      'tickSize': '0.01'},
#     'lotSizeFilter': {'maxTradingQty': '1100.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '11000.0',
#      'maxOrderQty': '1100.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ASTRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ASTR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649044122000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '33000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '330000',
#      'maxOrderQty': '33000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ATOMPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ATOM',
#     'quoteCoin': 'USD',
#     'launchTime': '1663757456000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '3500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '17500.0',
#      'maxOrderQty': '3500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'ATOMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ATOM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633910400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '12000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '120000.0',
#      'maxOrderQty': '12000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AUDIOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AUDIO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637884800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '25000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '250000.0',
#      'maxOrderQty': '25000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AVAXPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AVAX',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '2000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '10000.00',
#      'maxOrderQty': '2000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'AVAXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AVAX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1631664000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '7700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '77000.0',
#      'maxOrderQty': '7700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'AXSUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'AXS',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '5500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '55000.0',
#      'maxOrderQty': '5500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BAKEUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAKE',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648794979000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '17000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '170000.0',
#      'maxOrderQty': '17000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BALUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649405651000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '1400.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '14000.00',
#      'maxOrderQty': '1400.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BANDUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAND',
#     'quoteCoin': 'USDT',
#     'launchTime': '1645167116000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '25000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '250000.0',
#      'maxOrderQty': '25000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BATUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BAT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '23000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '230000.0',
#      'maxOrderQty': '23000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BCHUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BCH',
#     'quoteCoin': 'USDT',
#     'launchTime': '1514764800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '600.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '6000.00',
#      'maxOrderQty': '600.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BELUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BEL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1655445585000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '18000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '180000',
#      'maxOrderQty': '18000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BICOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BICO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638445217000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '1500.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '15000.0',
#      'maxOrderQty': '1500.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BITUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BIT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633910400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '82000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '820000.0',
#      'maxOrderQty': '82000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BLZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BLZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1654497673000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '83000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '830000',
#      'maxOrderQty': '83000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BNBPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNB',
#     'quoteCoin': 'USD',
#     'launchTime': '1664459242000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '1000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '5000.00',
#      'maxOrderQty': '1000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'BNBUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNB',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '1000.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '10000.00',
#      'maxOrderQty': '1000.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BNXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BNX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649229152000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '105.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1050.00',
#      'maxOrderQty': '105.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BOBAUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BOBA',
#     'quoteCoin': 'USDT',
#     'launchTime': '1649231761000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '3300.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '33000.0',
#      'maxOrderQty': '3300.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BSVUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BSV',
#     'quoteCoin': 'USDT',
#     'launchTime': '1639105708000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '60.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '600.00',
#      'maxOrderQty': '60.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BSWUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BSW',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648017126000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '26000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '260000',
#      'maxOrderQty': '26000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'BTCPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USD',
#     'launchTime': '1610604231000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '125.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.50',
#      'maxPrice': '999999.00',
#      'tickSize': '0.50'},
#     'lotSizeFilter': {'maxTradingQty': '20.000',
#      'minTradingQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '100.000',
#      'maxOrderQty': '20.000',
#      'minOrderQty': '0.001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'BTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1584230400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '100.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.50',
#      'maxPrice': '999999.00',
#      'tickSize': '0.50'},
#     'lotSizeFilter': {'maxTradingQty': '100.000',
#      'minTradingQty': '0.001',
#      'qtyStep': '0.001',
#      'postOnlyMaxOrderQty': '1000.000',
#      'maxOrderQty': '100.000',
#      'minOrderQty': '0.001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'C98USDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'C98',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CEEKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CEEK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1658127698000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '13000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '130000',
#      'maxOrderQty': '13000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CELOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CELO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1641367582000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '8700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '87000.0',
#      'maxOrderQty': '8700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CELRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CELR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '490000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '4900000',
#      'maxOrderQty': '490000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CHRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637193600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '42000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '420000.0',
#      'maxOrderQty': '42000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CHZPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHZ',
#     'quoteCoin': 'USD',
#     'launchTime': '1663815035000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '150000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '750000',
#      'maxOrderQty': '150000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'CHZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CHZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1633996800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '350000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '3500000',
#      'maxOrderQty': '350000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CKBUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CKB',
#     'quoteCoin': 'USDT',
#     'launchTime': '1644901148000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '6',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.000005',
#      'maxPrice': '9.999990',
#      'tickSize': '0.000005'},
#     'lotSizeFilter': {'maxTradingQty': '370000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '3700000',
#      'maxOrderQty': '370000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'COMPUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'COMP',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '270.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '2700.00',
#      'maxOrderQty': '270.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'COTIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'COTI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638445117000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '91000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '910000',
#      'maxOrderQty': '91000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CREAMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CREAM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1642405767000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '70.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '700.00',
#      'maxOrderQty': '70.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CROUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CRO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637625600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '120000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1200000',
#      'maxOrderQty': '120000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CRVUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CRV',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '35000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '350000.0',
#      'maxOrderQty': '35000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1652774270000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '690',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '6900',
#      'maxOrderQty': '690',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTKUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTK',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638444847000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '8600.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '86000.0',
#      'maxOrderQty': '8600.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CTSIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CTSI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648018511000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '39000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '390000',
#      'maxOrderQty': '39000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CVCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CVC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638285651000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '61000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '610000',
#      'maxOrderQty': '61000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'CVXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'CVX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1650440282000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
# ...
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '1100000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '11000000',
#      'maxOrderQty': '1100000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'TWTUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'TWT',
#     'quoteCoin': 'USDT',
#     'launchTime': '1668666261000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '10000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '100000.0',
#      'maxOrderQty': '10000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'UNFIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'UNFI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1653899789000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0005',
#      'maxPrice': '999.9990',
#      'tickSize': '0.0005'},
#     'lotSizeFilter': {'maxTradingQty': '4700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '47000.0',
#      'maxOrderQty': '4700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'UNIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'UNI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638230400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '6700.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '67000.0',
#      'maxOrderQty': '6700.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'USDCUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'USDC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1656399612000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '50000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '500000.0',
#      'maxOrderQty': '50000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'VETUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'VET',
#     'quoteCoin': 'USDT',
#     'launchTime': '1635120000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '640000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '6400000',
#      'maxOrderQty': '640000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'WAVESUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'WAVES',
#     'quoteCoin': 'USDT',
#     'launchTime': '1641368026000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.005',
#      'maxPrice': '9999.990',
#      'tickSize': '0.005'},
#     'lotSizeFilter': {'maxTradingQty': '4900.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '49000.0',
#      'maxOrderQty': '4900.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'WOOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'WOO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1636416000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '44000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '440000.0',
#      'maxOrderQty': '44000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XCNUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XCN',
#     'quoteCoin': 'USDT',
#     'launchTime': '1651132431000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '18000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '180000',
#      'maxOrderQty': '18000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XEMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XEM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638252824000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '210000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '2100000',
#      'maxOrderQty': '210000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XLMUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XLM',
#     'quoteCoin': 'USDT',
#     'launchTime': '1628726400000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00005',
#      'maxPrice': '99.99990',
#      'tickSize': '0.00005'},
#     'lotSizeFilter': {'maxTradingQty': '250000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '2500000',
#      'maxOrderQty': '250000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XMRUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XMR',
#     'quoteCoin': 'USDT',
#     'launchTime': '1640143015000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '140.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1400.00',
#      'maxOrderQty': '140.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XNOUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XNO',
#     'quoteCoin': 'USDT',
#     'launchTime': '1662076800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '4200',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '42000',
#      'maxOrderQty': '4200',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XRPPERP',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XRP',
#     'quoteCoin': 'USD',
#     'launchTime': '1659657600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '350000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '1750000',
#      'maxOrderQty': '350000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDC'},
#    {'symbol': 'XRPUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XRP',
#     'quoteCoin': 'USDT',
#     'launchTime': '0',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '50.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '2100000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '21000000',
#      'maxOrderQty': '2100000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'XTZUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'XTZ',
#     'quoteCoin': 'USDT',
#     'launchTime': '1514764800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '15000.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '150000.0',
#      'maxOrderQty': '15000.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'YFIUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'YFI',
#     'quoteCoin': 'USDT',
#     'launchTime': '1638930769000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '0',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '5', 'maxPrice': '9999990', 'tickSize': '5'},
#     'lotSizeFilter': {'maxTradingQty': '1.0000',
#      'minTradingQty': '0.0001',
#      'qtyStep': '0.0001',
#      'postOnlyMaxOrderQty': '10.0000',
#      'maxOrderQty': '1.0000',
#      'minOrderQty': '0.0001'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'YGGUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'YGG',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637625600000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '3',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.001',
#      'maxPrice': '1999.998',
#      'tickSize': '0.001'},
#     'lotSizeFilter': {'maxTradingQty': '7400.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '74000.0',
#      'maxOrderQty': '7400.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZECUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZEC',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637712000000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '180.00',
#      'minTradingQty': '0.01',
#      'qtyStep': '0.01',
#      'postOnlyMaxOrderQty': '1800.00',
#      'maxOrderQty': '180.00',
#      'minOrderQty': '0.01'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZENUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZEN',
#     'quoteCoin': 'USDT',
#     'launchTime': '1637884800000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '2',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.05',
#      'maxPrice': '99999.90',
#      'tickSize': '0.05'},
#     'lotSizeFilter': {'maxTradingQty': '440.0',
#      'minTradingQty': '0.1',
#      'qtyStep': '0.1',
#      'postOnlyMaxOrderQty': '4400.0',
#      'maxOrderQty': '440.0',
#      'minOrderQty': '0.1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZILUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZIL',
#     'quoteCoin': 'USDT',
#     'launchTime': '1643480306000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '5',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '25.00',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.00001',
#      'maxPrice': '19.99998',
#      'tickSize': '0.00001'},
#     'lotSizeFilter': {'maxTradingQty': '790000',
#      'minTradingQty': '10',
#      'qtyStep': '10',
#      'postOnlyMaxOrderQty': '7900000',
#      'maxOrderQty': '790000',
#      'minOrderQty': '10'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'},
#    {'symbol': 'ZRXUSDT',
#     'contractType': 'LinearPerpetual',
#     'status': 'Trading',
#     'baseCoin': 'ZRX',
#     'quoteCoin': 'USDT',
#     'launchTime': '1648453878000',
#     'deliveryTime': '0',
#     'deliveryFeeRate': '',
#     'priceScale': '4',
#     'leverageFilter': {'minLeverage': '1',
#      'maxLeverage': '12.50',
#      'leverageStep': '0.01'},
#     'priceFilter': {'minPrice': '0.0001',
#      'maxPrice': '199.9998',
#      'tickSize': '0.0001'},
#     'lotSizeFilter': {'maxTradingQty': '35000',
#      'minTradingQty': '1',
#      'qtyStep': '1',
#      'postOnlyMaxOrderQty': '350000',
#      'maxOrderQty': '35000',
#      'minOrderQty': '1'},
#     'unifiedMarginTrade': True,
#     'fundingInterval': 480,
#     'settleCoin': 'USDT'}],
#   'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1674896451803}

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## Transform data

# %%
positions = transform_positions(positions_raw)

positions
# Out:
#       user_id        symbol  side  size  position_value  entry_price  \
# 0    49436126  10000NFTUSDT  None     0               0            0
# 1    49436126  1000BONKUSDT  None     0               0            0
# 2    49436126   1000BTTUSDT  None     0               0            0
# 3    49436126  1000LUNCUSDT  None     0               0            0
# 4    49436126   1000XECUSDT  None     0               0            0
# ..        ...           ...   ...   ...             ...          ...
# 179  49436126       YGGUSDT  None     0               0            0
# 180  49436126       ZECUSDT  None     0               0            0
# 181  49436126       ZENUSDT  None     0               0            0
# 182  49436126       ZILUSDT  None     0               0            0
# 183  49436126       ZRXUSDT  None     0               0            0
#
#      liq_price  bust_price  leverage  auto_add_margin  ...  free_qty  \
# 0            0           0     10.00                0  ...         0
# 1            0           0      2.29                0  ...         0
# 2            0           0     10.00                0  ...         0
# 3            0           0     10.00                0  ...         0
# 4            0           0     10.00                0  ...         0
# ..         ...         ...       ...              ...  ...       ...
# 179          0           0     10.00                0  ...         0
# 180          0           0      4.32                0  ...         0
# 181          0           0     10.00                0  ...         0
# 182          0           0     10.00                0  ...         0
# 183          0           0     10.00                0  ...         0
#
#      tp_sl_mode  unrealised_pnl  deleverage_indicator  risk_id  stop_loss  \
# 0          Full               0                     0        1          0
# 1          Full               0                     0        1          0
# 2          Full               0                     0        1          0
# 3          Full               0                     0        1          0
# 4          Full               0                     0        1          0
# ..          ...             ...                   ...      ...        ...
# 179        Full               0                     0     1196          0
# 180        Full               0                     0     1211          0
# 181        Full               0                     0     1271          0
# 182        Full               0                     0        1          0
# 183        Full               0                     0        1          0
#
#     take_profit  trailing_stop  position_idx          mode
# 0             0              0             0  MergedSingle
# 1             0              0             0  MergedSingle
# 2             0              0             0  MergedSingle
# 3             0              0             0  MergedSingle
# 4             0              0             0  MergedSingle
# ..          ...            ...           ...           ...
# 179           0              0             0  MergedSingle
# 180           0              0             0  MergedSingle
# 181           0              0             0  MergedSingle
# 182           0              0             0  MergedSingle
# 183           0              0             0  MergedSingle
#
# [184 rows x 25 columns]

# %%
active_positions = parse_active_positions(positions, instruments_info)

active_positions
# Out:
# Empty DataFrame
# Columns: [user_id, symbol, side, size, position_value, entry_price, liq_price, bust_price, leverage, auto_add_margin, is_isolated, position_margin, occ_closing_fee, realised_pnl, cum_realised_pnl, free_qty, tp_sl_mode, unrealised_pnl, deleverage_indicator, risk_id, stop_loss, take_profit, trailing_stop, position_idx, mode, price_scale]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ![green-divider](resources/green_divider.png)
#
#
# ## Process data

# %%
# TODO: test please
place_trailing_stops(active_positions, exchange)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
